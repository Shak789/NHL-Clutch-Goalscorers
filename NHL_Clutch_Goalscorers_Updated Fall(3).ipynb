# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import requests
import json
import random
import pandas as pd
import datetime as dt
import numpy as np
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from pandas import DataFrame, Series
from patsy import dmatrices
from scipy import stats
from sklearn import metrics
from sklearn.metrics import (precision_score, recall_score, f1_score, 
                             confusion_matrix, ConfusionMatrixDisplay, 
                             average_precision_score, balanced_accuracy_score, 
                             matthews_corrcoef, roc_auc_score)
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
import pandas as pd
import requests
import time

def get_nhl_percentages(start_season=2018, end_season=2024):
    """
    Fetch and aggregate NHL player percentages data across multiple seasons.
    
    Parameters:
    start_season: int, starting year (e.g., 2018 for 2018-19 season)
    end_season: int, ending year (e.g., 2024 for 2023-24 season)
    
    Returns:
    DataFrame with player percentages aggregated across seasons
    """
    all_data = []
    
    for year in range(start_season, end_season):
        season_id = f"{year}{year+1}"
        url = f'https://api.nhle.com/stats/rest/en/skater/percentages?limit=-1&cayenneExp=seasonId={season_id}'
        
        try:
            response = requests.get(url)
            if response.status_code == 200:
                season_data = response.json()
                if 'data' in season_data:
                    df_season = pd.DataFrame(season_data['data'])
                    df_season['season'] = f"{year}-{year+1}"
                    all_data.append(df_season)
                    print(f"Successfully fetched data for season {year}-{year+1}")
            else:
                print(f"Failed to fetch data for season {year}-{year+1}: Status code {response.status_code}")
                
            time.sleep(1)  # Be respectful to the API
            
        except Exception as e:
            print(f"Error fetching data for season {year}-{year+1}: {str(e)}")
    
    if all_data:
        # Combine all seasons
        df_combined = pd.concat(all_data, ignore_index=True)
        
        # Aggregate stats per player
        df_aggregated = df_combined.groupby('playerId').agg({
            'lastName': 'first',
            'usatPrecentageClose': 'mean',
            'usatPercentageTied': 'mean',
            'satPercentageClose': 'mean',
            'satPercentageTied': 'mean',
            'season': 'count'  # Number of seasons played
        }).reset_index(drop = True)
        
        return df_aggregated
    else:
        return None

# Example usage
df = get_nhl_percentages(2018, 2024)

if df is not None:
    # Display some summary statistics
    print("\nDataset Summary:")
    print(f"Total unique players: {len(df)}")
    print("\nAggregated Stats Summary:")
    print(df.describe())
    
    # Save to CSV
    df.to_csv('nhl_aggregated_stats.csv', index=False)
# Out:
# Successfully fetched data for season 2018-2019
# Successfully fetched data for season 2019-2020
# Successfully fetched data for season 2020-2021
# Successfully fetched data for season 2021-2022
# Successfully fetched data for season 2022-2023
# Successfully fetched data for season 2023-2024
#
# Dataset Summary:
# Total unique players: 1558
#
# Aggregated Stats Summary:
#        usatPrecentageClose  usatPercentageTied  satPercentageClose  \
# count          1557.000000         1546.000000         1555.000000
# mean              0.478455            0.477650            0.477054
# std               0.084694            0.104980            0.075413
# min               0.000000            0.000000            0.000000
# 25%               0.448333            0.445000            0.447708
# 50%               0.485500            0.485196            0.484400
# 75%               0.515857            0.520333            0.514208
# max               1.000000            1.000000            1.000000
#
#        satPercentageTied       season
# count        1546.000000  1558.000000
# mean            0.477215     3.727214
# std             0.093537     2.096127
# min             0.000000     1.000000
# 25%             0.447000     2.000000
# 50%             0.486100     4.000000
# 75%             0.518313     6.000000
# max             1.000000     9.000000

# %%
df.columns
# Out:
# Index(['lastName', 'usatPrecentageClose', 'usatPercentageTied',
#        'satPercentageClose', 'satPercentageTied', 'season'],
#       dtype='object')

# %%
df.loc[df['lastName'] == 'Marchand']
# Out:
#      lastName  usatPrecentageClose  usatPercentageTied  satPercentageClose  \
# 107  Marchand               0.5755                0.58            0.569667
#
#      satPercentageTied  season
# 107              0.576       6

# %%
percentages_url = 'https://api.nhle.com/stats/rest/en/skater/percentages?limit=-1&cayenneExp=seasonId=20232024'
percentages_resp = requests.get(percentages_url)
percentages_json = percentages_resp.json()

# %%
df_percentages = DataFrame(percentages_json['data'])

# %%
df_percentages
# Out:
#      gamesPlayed     lastName  playerId positionCode  satPercentage  \
# 0             64        Necas   8480039            C          0.528
# 1             49  Deslauriers   8475235            L          0.448
# 2             55    Heiskanen   8480036            D          0.526
# 3             78      Johnson   8474870            C          0.504
# 4             54        Soucy   8477369            D          0.433
# ..           ...          ...       ...          ...            ...
# 940           28      Asplund   8479335            C          0.443
# 941            2     Gauthier   8477512            C          0.208
# 942           33        Jones   8478452            D          0.491
# 943           45    Jankowski   8476873            C          0.447
# 944           20     Wallmark   8478027            C          0.470
#
#      satPercentageAhead  satPercentageBehind  satPercentageClose  \
# 0                 0.519                0.551               0.525
# 1                 0.352                0.513               0.435
# 2                 0.470                0.528               0.537
# 3                 0.464                0.553               0.535
# 4                 0.443                0.442               0.443
# ..                  ...                  ...                 ...
# 940               0.411                0.476               0.421
# 941               0.428                0.500               0.142
# 942               0.451                0.568               0.473
# 943               0.448                0.423               0.445
# 944               0.455                0.471               0.469
#
#      satPercentageTied  satRelative  ...  skaterShootingPlusSavePct5v5  \
# 0                0.525       -0.012  ...                         1.026
# 1                0.440       -0.055  ...                         0.970
# 2                0.568       -0.007  ...                         0.979
# 3                0.522       -0.010  ...                         1.011
# 4                0.417       -0.047  ...                         1.065
# ..                 ...          ...  ...                           ...
# 940              0.408       -0.012  ...                         0.996
# 941              0.066       -0.281  ...                         1.000
# 942              0.460       -0.009  ...                         0.958
# 943              0.464       -0.075  ...                         1.017
# 944              0.479       -0.031  ...                         0.956
#
#      teamAbbrevs timeOnIcePerGame5v5 usatPercentage  usatPercentageAhead  \
# 0            CAR             819.937          0.529                0.525
# 1            ANA             661.122          0.448                0.356
# 2            DAL            1148.400          0.524                0.492
# 3            TBL             654.346          0.507                0.492
# 4            MIN             836.203          0.449                0.472
# ..           ...                 ...            ...                  ...
# 940          BUF             707.500          0.436                0.402
# 941          ARI             404.500          0.176                0.333
# 942          EDM             773.242          0.500                0.472
# 943          PIT             516.622          0.456                0.470
# 944      CHI,FLA             596.650          0.455                0.439
#
#      usatPercentageBehind usatPercentageTied  usatPrecentageClose  \
# 0                   0.542              0.526                0.525
# 1                   0.498              0.454                0.433
# 2                   0.501              0.574                0.543
# 3                   0.523              0.516                0.544
# 4                   0.440              0.434                0.463
# ..                    ...                ...                  ...
# 940                 0.487              0.378                0.403
# 941                 0.500              0.000                0.133
# 942                 0.561              0.466                0.475
# 943                 0.467              0.437                0.442
# 944                 0.442              0.474                0.461
#
#      usatRelative  zoneStartPct5v5
# 0          -0.006            0.494
# 1          -0.045            0.344
# 2          -0.004            0.501
# 3          -0.008            0.533
# 4          -0.037            0.347
# ..            ...              ...
# 940        -0.010            0.426
# 941        -0.250            0.333
# 942         0.006            0.546
# 943        -0.066            0.303
# 944        -0.046            0.488
#
# [945 rows x 25 columns]

# %%
df_percentages = DataFrame(percentages_json['data'])
df_percentages_filtered = df_percentages.loc[(df_percentages['positionCode'] != 'D') & (df_percentages['gamesPlayed'] >= 20)]
df_percentages_filtered = df_percentages_filtered.reset_index(drop=True)
df_percentages_filtered.drop(['skaterSavePct5v5', 'seasonId','shootingPct5v5', 'timeOnIcePerGame5v5', 'zoneStartPct5v5', 'satPercentage', 'satPercentageBehind', 'satPercentageAhead', 'satRelative', 'skaterShootingPlusSavePct5v5', 'usatPercentage', 'usatPercentageAhead', 'usatPercentageBehind', 'usatRelative'], axis=1, inplace=True)
df_percentages_filtered = df_percentages_filtered[['playerId', 'skaterFullName', 'lastName', 'positionCode', 'teamAbbrevs', 'gamesPlayed', 'shootsCatches','satPercentageClose',
 'satPercentageTied','usatPercentageTied', 'usatPrecentageClose']]
df_percentages_filtered['tiedPerformance'] = (df_percentages_filtered['usatPercentageTied'] + df_percentages_filtered['satPercentageTied'])/2
df_percentages_filtered['closePerformance'] = (df_percentages_filtered['usatPrecentageClose'] + df_percentages_filtered['satPercentageClose'])/2

# %%
df_percentages_filtered
# Out:
#      playerId     skaterFullName    lastName positionCode teamAbbrevs  \
# 0     8478028   Fredrik Olofsson    Olofsson            L         COL
# 1     8475763        Kevin Hayes       Hayes            R         STL
# 2     8471698         T.J. Oshie       Oshie            R         WSH
# 3     8482259       Bobby McMann      McMann            C         TOR
# 4     8480748    Kiefer Sherwood    Sherwood            L         NSH
# ..        ...                ...         ...          ...         ...
# 469   8481553        Bobby Brink       Brink            R         PHI
# 470   8477951      Nick Schmaltz    Schmaltz            C         ARI
# 471   8478233  Andrew Mangiapane  Mangiapane            L         CGY
# 472   8482652       Walker Duehr       Duehr            R         CGY
# 473   8478400        Colin White       White            C     PIT,MTL
#
#      gamesPlayed shootsCatches  satPercentageClose  satPercentageTied  \
# 0             57             L               0.464              0.436
# 1             79             L               0.450              0.443
# 2             56             R               0.433              0.416
# 3             56             L               0.523              0.518
# 4             74             R               0.520              0.535
# ..           ...           ...                 ...                ...
# 469           57             R               0.475              0.479
# 470           79             R               0.515              0.483
# 471           75             L               0.517              0.506
# 472           40             R               0.429              0.491
# 473           28             R               0.468              0.500
#
#      usatPercentageTied  usatPrecentageClose  tiedPerformance  \
# 0                 0.401                0.436           0.4185
# 1                 0.430                0.436           0.4365
# 2                 0.411                0.431           0.4135
# 3                 0.509                0.530           0.5135
# 4                 0.534                0.522           0.5345
# ..                  ...                  ...              ...
# 469               0.508                0.502           0.4935
# 470               0.484                0.509           0.4835
# 471               0.537                0.542           0.5215
# 472               0.512                0.429           0.5015
# 473               0.504                0.482           0.5020
#
#      closePerformance
# 0              0.4500
# 1              0.4430
# 2              0.4320
# 3              0.5265
# 4              0.5210
# ..                ...
# 469            0.4885
# 470            0.5120
# 471            0.5295
# 472            0.4290
# 473            0.4750
#
# [474 rows x 13 columns]

# %%
summary_url = 'https://api.nhle.com/stats/rest/en/skater/summary?limit=-1&cayenneExp=seasonId=20232024'
summary_resp = requests.get(summary_url)
summary_json = summary_resp.json()

# %%
df_summary = DataFrame(summary_json['data'])
df_summary_filtered = df_summary.loc[(df_summary['positionCode'] != 'D') & (df_summary['gamesPlayed'] >= 20)]
df_summary_filtered = df_summary_filtered.reset_index(drop=True)
df_summary_filtered.drop(['assists', 'evGoals', 'evPoints', 'faceoffWinPct', 'penaltyMinutes', 'plusMinus', 'pointsPerGame', 'ppGoals', 'ppPoints', 'shPoints','shootingPct', 'shootsCatches', 'shots', 'timeOnIcePerGame', 'seasonId'], axis=1, inplace=True)
df_summary_filtered = df_summary_filtered[['playerId', 'skaterFullName', 'lastName', 'positionCode', 'teamAbbrevs', 'gamesPlayed', 'goals', 'gameWinningGoals','otGoals', 'points']]
df_summary_filtered['clutchGoals'] = df_summary_filtered['gameWinningGoals'] + df_summary_filtered['otGoals']
df_summary_filtered['clutchgoalsRatio'] = df_summary_filtered['clutchGoals'] / np.maximum(df_summary_filtered['goals'],1)

# %%
df_summary_filtered
# Out:
#      playerId     skaterFullName  lastName positionCode teamAbbrevs  \
# 0     8480039       Martin Necas     Necas            C         CAR
# 1     8478028   Fredrik Olofsson  Olofsson            L         COL
# 2     8475763        Kevin Hayes     Hayes            R         STL
# 3     8471698         T.J. Oshie     Oshie            R         WSH
# 4     8482259       Bobby McMann    McMann            C         TOR
# ..        ...                ...       ...          ...         ...
# 469   8482125    Alexander Holtz     Holtz            R         NJD
# 470   8482157        Will Cuylle    Cuylle            L         NYR
# 471   8479367   William Lockwood  Lockwood            R         FLA
# 472   8480068      Ryan Poehling  Poehling            C         PHI
# 473   8478477  Mitchell Stephens  Stephens            C         MTL
#
#      gamesPlayed  goals  gameWinningGoals  otGoals  points  clutchGoals  \
# 0             88     28                 3        2      62            5
# 1             57      3                 1        0       9            1
# 2             79     13                 2        0      29            2
# 3             56     12                 4        0      26            4
# 4             56     15                 0        0      24            0
# ..           ...    ...               ...      ...     ...          ...
# 469           82     16                 3        0      28            3
# 470           97     14                 2        0      23            2
# 471           26      0                 0        0       1            0
# 472           77     11                 1        0      28            1
# 473           23      2                 0        0       3            0
#
#      clutchgoalsRatio
# 0            0.178571
# 1            0.333333
# 2            0.153846
# 3            0.333333
# 4            0.000000
# ..                ...
# 469          0.187500
# 470          0.142857
# 471          0.000000
# 472          0.090909
# 473          0.000000
#
# [474 rows x 12 columns]

# %%
df_players_merged = pd.merge(df_percentages_filtered, df_summary_filtered, on = 'playerId', how = 'right', suffixes=('', '_x'))

# %%
df_players_merged.columns
# Out:
# Index(['playerId', 'skaterFullName', 'lastName', 'positionCode', 'teamAbbrevs',
#        'gamesPlayed', 'shootsCatches', 'satPercentageClose',
#        'satPercentageTied', 'usatPercentageTied', 'usatPrecentageClose',
#        'tiedPerformance', 'closePerformance', 'skaterFullName_x', 'lastName_x',
#        'positionCode_x', 'teamAbbrevs_x', 'gamesPlayed_x', 'goals',
#        'gameWinningGoals', 'otGoals', 'points', 'clutchGoals',
#        'clutchgoalsRatio'],
#       dtype='object')

# %%
df_players_merged.drop(columns = ['skaterFullName_x', 'lastName_x', 'positionCode_x', 'teamAbbrevs_x', 'gamesPlayed_x'], axis=1, inplace=True)

# %%
df_players_merged
# Out:
#      playerId     skaterFullName  lastName positionCode teamAbbrevs  \
# 0     8480039       Martin Necas     Necas            C         CAR
# 1     8478028   Fredrik Olofsson  Olofsson            L         COL
# 2     8475763        Kevin Hayes     Hayes            R         STL
# 3     8471698         T.J. Oshie     Oshie            R         WSH
# 4     8482259       Bobby McMann    McMann            C         TOR
# ..        ...                ...       ...          ...         ...
# 471   8482125    Alexander Holtz     Holtz            R         NJD
# 472   8482157        Will Cuylle    Cuylle            L         NYR
# 473   8479367   William Lockwood  Lockwood            R         FLA
# 474   8480068      Ryan Poehling  Poehling            C         PHI
# 475   8478477  Mitchell Stephens  Stephens            C         MTL
#
#      gamesPlayed shootsCatches  satPercentageClose  satPercentageTied  \
# 0             88             R               0.609              0.611
# 1             57             L               0.464              0.436
# 2             79             L               0.450              0.443
# 3             56             R               0.433              0.416
# 4             56             L               0.523              0.518
# ..           ...           ...                 ...                ...
# 471           82             R               0.467              0.447
# 472           97             L               0.485              0.493
# 473           26             R               0.554              0.531
# 474           77             L               0.484              0.448
# 475           23             R               0.412              0.444
#
#      usatPercentageTied  usatPrecentageClose  tiedPerformance  \
# 0                 0.600                0.599           0.6055
# 1                 0.401                0.436           0.4185
# 2                 0.430                0.436           0.4365
# 3                 0.411                0.431           0.4135
# 4                 0.509                0.530           0.5135
# ..                  ...                  ...              ...
# 471               0.437                0.456           0.4420
# 472               0.516                0.501           0.5045
# 473               0.485                0.530           0.5080
# 474               0.497                0.524           0.4725
# 475               0.493                0.444           0.4685
#
#      closePerformance  goals  gameWinningGoals  otGoals  points  clutchGoals  \
# 0              0.6040     28                 3        2      62            5
# 1              0.4500      3                 1        0       9            1
# 2              0.4430     13                 2        0      29            2
# 3              0.4320     12                 4        0      26            4
# 4              0.5265     15                 0        0      24            0
# ..                ...    ...               ...      ...     ...          ...
# 471            0.4615     16                 3        0      28            3
# 472            0.4930     14                 2        0      23            2
# 473            0.5420      0                 0        0       1            0
# 474            0.5040     11                 1        0      28            1
# 475            0.4280      2                 0        0       3            0
#
#      clutchgoalsRatio
# 0            0.178571
# 1            0.333333
# 2            0.153846
# 3            0.333333
# 4            0.000000
# ..                ...
# 471          0.187500
# 472          0.142857
# 473          0.000000
# 474          0.090909
# 475          0.000000
#
# [476 rows x 19 columns]

# %%
df_players_merged.rename(columns={'usatPrecentageClose': 'usatPercentageClose'}, inplace=True)

# %%
df_players_merged
# Out:
#      playerId     skaterFullName  lastName positionCode teamAbbrevs  \
# 0     8480039       Martin Necas     Necas            C         CAR
# 1     8478028   Fredrik Olofsson  Olofsson            L         COL
# 2     8475763        Kevin Hayes     Hayes            R         STL
# 3     8471698         T.J. Oshie     Oshie            R         WSH
# 4     8482259       Bobby McMann    McMann            C         TOR
# ..        ...                ...       ...          ...         ...
# 471   8482125    Alexander Holtz     Holtz            R         NJD
# 472   8482157        Will Cuylle    Cuylle            L         NYR
# 473   8479367   William Lockwood  Lockwood            R         FLA
# 474   8480068      Ryan Poehling  Poehling            C         PHI
# 475   8478477  Mitchell Stephens  Stephens            C         MTL
#
#      gamesPlayed shootsCatches  satPercentageClose  satPercentageTied  \
# 0             88             R               0.609              0.611
# 1             57             L               0.464              0.436
# 2             79             L               0.450              0.443
# 3             56             R               0.433              0.416
# 4             56             L               0.523              0.518
# ..           ...           ...                 ...                ...
# 471           82             R               0.467              0.447
# 472           97             L               0.485              0.493
# 473           26             R               0.554              0.531
# 474           77             L               0.484              0.448
# 475           23             R               0.412              0.444
#
#      usatPercentageTied  usatPercentageClose  tiedPerformance  \
# 0                 0.600                0.599           0.6055
# 1                 0.401                0.436           0.4185
# 2                 0.430                0.436           0.4365
# 3                 0.411                0.431           0.4135
# 4                 0.509                0.530           0.5135
# ..                  ...                  ...              ...
# 471               0.437                0.456           0.4420
# 472               0.516                0.501           0.5045
# 473               0.485                0.530           0.5080
# 474               0.497                0.524           0.4725
# 475               0.493                0.444           0.4685
#
#      closePerformance  goals  gameWinningGoals  otGoals  points  clutchGoals  \
# 0              0.6040     28                 3        2      62            5
# 1              0.4500      3                 1        0       9            1
# 2              0.4430     13                 2        0      29            2
# 3              0.4320     12                 4        0      26            4
# 4              0.5265     15                 0        0      24            0
# ..                ...    ...               ...      ...     ...          ...
# 471            0.4615     16                 3        0      28            3
# 472            0.4930     14                 2        0      23            2
# 473            0.5420      0                 0        0       1            0
# 474            0.5040     11                 1        0      28            1
# 475            0.4280      2                 0        0       3            0
#
#      clutchgoalsRatio
# 0            0.178571
# 1            0.333333
# 2            0.153846
# 3            0.333333
# 4            0.000000
# ..                ...
# 471          0.187500
# 472          0.142857
# 473          0.000000
# 474          0.090909
# 475          0.000000
#
# [476 rows x 19 columns]

# %%
percentages  = ['satPercentageClose', 'satPercentageTied','usatPercentageTied', 'usatPercentageClose', 'tiedPerformance', 'closePerformance', 'clutchgoalsRatio']

for stat in percentages:
    df_players_merged[stat] *= 100

# %%
df_players_merged[['tiedPerformance', 'closePerformance', 'clutchgoalsRatio']].describe(percentiles=[0.75, 0.8, 0.9])
# Out:
#        tiedPerformance  closePerformance  clutchgoalsRatio
# count       476.000000        476.000000        476.000000
# mean         49.333088         49.260504         14.775629
# std           5.277524          4.856933         12.319454
# min          35.000000         34.900000          0.000000
# 50%          49.575000         49.650000         14.550265
# 75%          53.050000         52.600000         22.617302
# 80%          54.000000         53.300000         25.000000
# 90%          55.800000         54.925000         31.009615
# max          63.150000         61.650000         66.666667

# %%
gameWinningGoalsQuantile = df_players_merged['clutchgoalsRatio'].quantile(0.8)

def binary_clutchness(row):
    clutchness = (row['goals'] >= 25)
    if clutchness:
        return 1
    else:
        return 0
        
df_players_merged['clutch_performance'] = df_players_merged.apply(binary_clutchness, axis=1)

# %%
df_players_merged['clutch_performance'].value_counts()
# Out:
# clutch_performance
# 0    377
# 1     99
# Name: count, dtype: int64

# %%
key = ['Non-Clutch Goalscorer', 'Clutch Goalscorer',]

plt.pie(df_players_merged['clutch_performance'].value_counts(), labels=key, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Clutch vs. Non-Clutch Goalscorers')
plt.axis('equal') 
plt.show()

# %%
x_var = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageClose', 'satPercentageTied', 'gameWinningGoals']
y_var = ['clutch_performance']
train, test = train_test_split(df_players_merged, test_size = 0.3)

xgb_model = xgb.XGBClassifier(n_estimators=100, eval_metric='mlogloss')
xgb_model.fit(train[x_var], train[y_var])

test['xgb_clutch_type'] = xgb_model.predict(test[x_var])
test['xgb_correct'] = (test['xgb_clutch_type'] == test['clutch_performance'])
xgb_accuracy = test['xgb_correct'].mean()
xgb_accuracy
# Out:
# 0.972027972027972

# %%
'''import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import precision_score, recall_score, average_precision_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from scipy.stats import friedmanchisquare

x_var = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageClose', 'satPercentageTied', 'gameWinningGoals']
y_var = 'clutch_performance'

x = df_players_merged[x_var]
y = df_players_merged[y_var]

models = {
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators = 100),
    'XGBoost': xgb.XGBClassifier(eval_metric='logloss')
}

metrics = {name: {'precision': [], 'recall': [], 'auc_pr': [], 'f1_score': []} for model_name in models}
def evaluate_model(model, x, y):
    precision_scores = []
    recall_scores = []
    auc_pr_scores = []
    f1_scores = []
    
    skf = StratifiedKFold(n_splits = 5)

    for train_index, test_index in skf.split(x, y):
        x_train_fold, x_test_fold = x.iloc[train_index], x.iloc[test_index]
        y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]

        model.fit(x_train_fold, y_train_fold)
        y_true = y_test_fold

        y_pred = model.predict(x_test_fold)
        y_pred_proba = model.predict_proba(x_test_fold)[:, 1]
            

        precision_scores.append(precision_score(y_true, y_pred))
        recall_scores.append(recall_score(y_true, y_pred))
        auc_pr_scores.append(average_precision_score(y_true, y_pred_proba))
        f1_scores.append(f1_score(y_true, y_pred))

    return {
        'precision': precision_scores,
        'recall': recall_scores,
        'auc_pr': auc_pr_scores,
        'f1_score': f1_scores
    }


for model_name, model in models.items():
    results = evaluate_model(model, x, y)
    for metric in metrics[model_name]:
        metrics[model_name][metric] = results[metric]

data_for_tests = {
    'precision': [metrics[name]['precision'] for name in models],
    'recall': [metrics[name]['recall'] for name in models],
    'auc_pr': [metrics[name]['auc_pr'] for name in models],
    'f1_score': [metrics[name]['f1_score'] for name in models],
}

for metric, data in data_for_tests.items():
    stat, p = friedmanchisquare(*data)
    print(f'Friedman test for {metric.capitalize()}: statistic={stat}, p-value={p}')''
# Out:
#   Cell In[20], line 1
#     '''import pandas as pd
#     ^
# SyntaxError: incomplete input

# %%
'''for model_name in metrics.keys():
    print(f"{model_name} recall: {metrics[model_name]['recall']}")'''

# %%
'''import pandas as pd

# Extract precision scores
precision_data = []

for model_name, metrics_values in metrics.items():
    precision_scores = metrics_values['recall']
    
    for fold_index, score in enumerate(precision_scores):
        precision_data.append({
            'Model': model_name,
            'Fold': fold_index + 1,
            'Precision': score
        })

precision_df = pd.DataFrame(precision_data)

knn_precision = precision_df.loc[precision_df['Model'] == 'KNN', 'Precision'].values
random_forest_precision = precision_df.loc[precision_df['Model'] == 'Random Forest', 'Precision'].values
xgboost_forest_precision = precision_df.loc[precision_df['Model'] == 'XGBoost', 'Precision'].values

res = friedmanchisquare(knn_precision, random_forest_precision, xgboost_forest_precision)
print(res.statistic)
print(res.pvalue)

precision_df['Rank'] = precision_df.groupby('Fold')['Precision'].rank(ascending=False)

rank_sum = precision_df.groupby('Model')['Rank'].sum().reset_index()
rank_sum.columns = ['Model', 'Rank_Sum']
rank_sum['Sum Squared'] = rank_sum['Rank_Sum'] ** 2

chi_square = 12 / (10 * 3 * (3 + 1)) * rank_sum['Sum Squared'].sum() - 3 * 10 * (3 + 1)

print(chi_square)
'''

# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, average_precision_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import seaborn as sns
import scikit_posthocs as sp


x_var = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageClose', 'satPercentageTied', 'gameWinningGoals']
y_var = 'clutch_performance'

x = df_players_merged[x_var]
y = df_players_merged[y_var]

models = {
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators = 100),
    'XGBoost': xgb.XGBClassifier(eval_metric='logloss')
    }

metrics_combined =  {'precision': [], 
     'recall': [], 
     'auc_pr': [], 
     'f1_score': []}

skf = StratifiedKFold(n_splits = 10)

def evaluate_model(model, x, y):
    precision_scores = []
    recall_scores = []
    auc_pr_scores = []
    f1_scores = []
    
    for train_index, test_index in skf.split(x, y):
        x_train_fold, x_test_fold = x.iloc[train_index], x.iloc[test_index]
        y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    
        model.fit(x_train_fold, y_train_fold)
        y_true = y_test_fold
    
        y_pred = model.predict(x_test_fold)
        y_pred_proba = model.predict_proba(x_test_fold)[:, 1]
                
    
        precision_scores.append(precision_score(y_true, y_pred))
        recall_scores.append(recall_score(y_true, y_pred))
        auc_pr_scores.append(average_precision_score(y_true, y_pred_proba))
        f1_scores.append(f1_score(y_true, y_pred))

    results = {
        'precision': precision_scores,
        'recall': recall_scores,
        'auc_pr': auc_pr_scores,
        'f1_score': f1_scores
    }
               
    return results
    
for model_name, model in models.items():
    scores = evaluate_model(model, x, y)
    for metric in scores:
        metrics_combined[metric].append(scores[metric])

sns.set(rc={'figure.figsize': (18, 9)}, font_scale = 3)
figure, axes = plt.subplots(1, 3, sharex = True, sharey= True)

i = 0

for name in metrics_combined:
    stat, p = friedmanchisquare(*metrics_combined[name])
    print(f'Friedman test for {name.capitalize()}: statistic={stat}, p-value={p}')
    
    if p < 0.05:
        df_scores = pd.DataFrame(metrics_combined[name]).T
        df_scores.columns = models.keys() 

        metrics_summary = df_scores.agg(['mean']).T
        print(f'\nMetrics Summary for {name.capitalize()} (p < 0.05):\n', metrics_summary)

        
        df_long = df_scores.melt(var_name='Model', value_name='Score')
        
        df = sp.posthoc_conover(df_long, group_col='Model', val_col='Score', p_adjust='holm')
        print(df)

        similarity_matrix = pd.DataFrame(df, index = models.keys())

        heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5',  'square': True}

        sub_ax, sub_c = sp.sign_plot(df, **heatmap_args, ax=axes[i])
        sub_ax.set_title(name.replace("_", " ").upper())
        i += 1
        if i >= 3:
            break

plt.show()
# Out:
# Friedman test for Precision: statistic=10.173913043478276, p-value=0.006176790235910856
#
# Metrics Summary for Precision (p < 0.05):
#                     mean
# KNN            0.798636
# Random Forest  0.796890
# XGBoost        0.712716
#                     KNN  Random Forest   XGBoost
# KNN            1.000000       0.979620  0.549135
# Random Forest  0.979620       1.000000  0.549135
# XGBoost        0.549135       0.549135  1.000000
# Friedman test for Recall: statistic=9.08333333333334, p-value=0.0106556323585439
#
# Metrics Summary for Recall (p < 0.05):
#                     mean
# KNN            0.535556
# Random Forest  0.636667
# XGBoost        0.645556
#                     KNN  Random Forest   XGBoost
# KNN            1.000000       0.447837  0.447837
# Random Forest  0.447837       1.000000  0.916342
# XGBoost        0.447837       0.916342  1.000000
# Friedman test for Auc_pr: statistic=12.200000000000017, p-value=0.0022428677194857843
#
# Metrics Summary for Auc_pr (p < 0.05):
#                     mean
# KNN            0.712488
# Random Forest  0.773572
# XGBoost        0.712939
#                     KNN  Random Forest   XGBoost
# KNN            1.000000       0.647441  0.860484
# Random Forest  0.647441       1.000000  0.647441
# XGBoost        0.860484       0.647441  1.000000

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

x_var = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageClose', 'satPercentageTied', 'gameWinningGoals']
y_var = 'clutch_performance'

X = df_players_merged[x_var]
y = df_players_merged[y_var]

train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.2)

xgb_model = xgb.XGBClassifier(n_estimators=100, eval_metric='logloss')
xgb_model.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.model_selection import cross_validate

scoring = ['accuracy', 'precision', 'recall', 'f1', 'average_precision']

scores = cross_validate(xgb_model, X, y, cv=5, scoring=scoring)

df = pd.DataFrame.from_dict(scores)

df.mean()
# Out:
# fit_time                  0.105020
# score_time                0.032894
# test_accuracy             0.861294
# test_precision            0.705873
# test_recall               0.606316
# test_f1                   0.649440
# test_average_precision    0.700155
# dtype: float64

# %%
from sklearn.model_selection import learning_curve

cv = StratifiedKFold(n_splits=10)

train_sizes, train_scores, valid_scores = learning_curve(
    xgb_model, X, y,
    train_sizes=np.linspace(0.1, 1, 30), 
    cv=cv, 
    scoring='neg_log_loss',  
    n_jobs=-1  
)

train_scores_mean = -np.mean(train_scores, axis=1)
valid_scores_mean = -np.mean(valid_scores, axis=1)
train_scores_std = -np.std(train_scores, axis=1)
valid_scores_std = -np.std(valid_scores, axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score', color='blue', linewidth=2)
plt.plot(train_sizes, valid_scores_mean, label='Validation score', color='orange', linewidth=2)
plt.legend() 
plt.xlabel('Training Size')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.show()

# %%
train_scores_smooth = pd.Series(train_scores_mean).ewm(span=10).mean()
valid_scores_smooth = pd.Series(valid_scores_mean).ewm(span=10).mean()

plt.plot(train_sizes, train_scores_smooth, label='Training score', color='blue', linewidth=2)
plt.plot(train_sizes, valid_scores_smooth, label='Cross-validation score', color='orange', linewidth=2)

plt.xlabel('Training Size')
plt.ylabel('Log Loss')
plt.title('Learning Curves XGBoost')
plt.show()

# %%
plot_importance(xgb_model)
plt.show()

# %%
x_var_adjusted = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageTied', 'satPercentageClose']
y_var = 'clutch_performance'

X_adjusted = df_players_merged[x_var_adjusted]
y = df_players_merged[y_var]

train_x, test_x, train_y, test_y = train_test_split(X_adjusted, y, test_size=0.2, random_state=50)

xgb_model_adjusted = xgb.XGBClassifier(n_estimators=100, eval_metric='logloss')
xgb_model_adjusted.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from skopt import BayesSearchCV
import xgboost as xgb
import time
import math

scale_pos_weight = math.sqrt((df_players_merged['clutch_performance'] == 0).sum() / (df_players_merged['clutch_performance'] == 1).sum())

param_grid = {
    'max_depth': [1,3,5],
    'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
    'n_estimators': [100, 200, 300],
    'scale_pos_weight': [scale_pos_weight],
    'min_child_weight': [1, 3, 5],
    'learning_rate': [0.1, 0.3, 0.6, 0.8, 1.0],
    'reg_alpha': [0.1, 0.5, 1.0],
    'reg_lambda': [0.1, 0.5, 1.0],
    'colsample_bytree': [0.3, 0.5, 0.8] 
}

fit_params = {
'early_stopping_rounds': 15,
}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold
from skopt import BayesSearchCV
import xgboost as xgb

cv = StratifiedKFold(n_splits=10)

accuracy_list = []
precision_list = []
recall_list = []
f1_list = []
best_hyperparams_list = []

for _ in range(6):

    rs = np.random.randint(1, 1000)
    
    bayes_search = BayesSearchCV(xgb_model_adjusted, param_grid, cv=cv, n_iter= 20, n_jobs=-1, random_state = rs, fit_params = fit_params)
    evalset = [(train_x, train_y), (test_x, test_y)]
    bayes_search.fit(X_adjusted, y, eval_set=evalset)

    xgb_best_model = bayes_search.best_estimator_
    results = xgb_best_model.evals_result()

    pyplot.plot(results['validation_0']['logloss'], label=f'Train Logloss (RS={rs})')
    pyplot.plot(results['validation_1']['logloss'], label=f'Validation Logloss (RS={rs})')

    pyplot.legend()
    pyplot.show()

    y_pred = xgb_best_model.predict(test_x)
    y_pred_prob = xgb_best_model.predict_proba(test_x)[:, 1]

    accuracy = accuracy_score(test_y, y_pred)
    precision = precision_score(test_y, y_pred)
    recall = recall_score(test_y, y_pred)
    f1 = f1_score(test_y, y_pred)

    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

    best_hyperparams_list.append(bayes_search.best_params_)


print("Average Accuracy:", np.mean(accuracy_list))
print("Average Precision:", np.mean(precision_list))
print("Average Recall:", np.mean(recall_list))
print("Average F1 Score:", np.mean(f1_list))

hyperparams_df = pd.DataFrame(best_hyperparams_list)
averaged_hyperparams = hyperparams_df.mean()
print("Averaged Hyperparameters:")
print(averaged_hyperparams)
# Out:
# [0]	validation_0-logloss:0.53382	validation_1-logloss:0.54823
# [1]	validation_0-logloss:0.51093	validation_1-logloss:0.52623
# [2]	validation_0-logloss:0.49380	validation_1-logloss:0.51077
# [3]	validation_0-logloss:0.48073	validation_1-logloss:0.49686
# [4]	validation_0-logloss:0.46362	validation_1-logloss:0.48064
# [5]	validation_0-logloss:0.44889	validation_1-logloss:0.47390
# [6]	validation_0-logloss:0.43788	validation_1-logloss:0.45816
# [7]	validation_0-logloss:0.42892	validation_1-logloss:0.44259
# [8]	validation_0-logloss:0.42121	validation_1-logloss:0.43583
# [9]	validation_0-logloss:0.41222	validation_1-logloss:0.42428
# [10]	validation_0-logloss:0.40760	validation_1-logloss:0.41751
# [11]	validation_0-logloss:0.40274	validation_1-logloss:0.41282
# [12]	validation_0-logloss:0.39705	validation_1-logloss:0.40645
# [13]	validation_0-logloss:0.39210	validation_1-logloss:0.39897
# [14]	validation_0-logloss:0.38662	validation_1-logloss:0.39554
# [15]	validation_0-logloss:0.38325	validation_1-logloss:0.38993
# [16]	validation_0-logloss:0.37543	validation_1-logloss:0.38605
# [17]	validation_0-logloss:0.37211	validation_1-logloss:0.38439
# [18]	validation_0-logloss:0.36571	validation_1-logloss:0.37834
# [19]	validation_0-logloss:0.36144	validation_1-logloss:0.37395
# [20]	validation_0-logloss:0.35723	validation_1-logloss:0.37142
# [21]	validation_0-logloss:0.35348	validation_1-logloss:0.36844
# [22]	validation_0-logloss:0.35017	validation_1-logloss:0.36689
# [23]	validation_0-logloss:0.34707	validation_1-logloss:0.35885
# [24]	validation_0-logloss:0.34394	validation_1-logloss:0.35627
# [25]	validation_0-logloss:0.34067	validation_1-logloss:0.35045
# [26]	validation_0-logloss:0.33844	validation_1-logloss:0.34839
# [27]	validation_0-logloss:0.33776	validation_1-logloss:0.34914
# [28]	validation_0-logloss:0.33202	validation_1-logloss:0.34715
# [29]	validation_0-logloss:0.32945	validation_1-logloss:0.34455
# [30]	validation_0-logloss:0.32374	validation_1-logloss:0.34427
# [31]	validation_0-logloss:0.31866	validation_1-logloss:0.33808
# [32]	validation_0-logloss:0.31716	validation_1-logloss:0.33407
# [33]	validation_0-logloss:0.31327	validation_1-logloss:0.33328
# [34]	validation_0-logloss:0.30926	validation_1-logloss:0.32974
# [35]	validation_0-logloss:0.30300	validation_1-logloss:0.32654
# [36]	validation_0-logloss:0.29886	validation_1-logloss:0.31981
# [37]	validation_0-logloss:0.29556	validation_1-logloss:0.32005
# [38]	validation_0-logloss:0.29341	validation_1-logloss:0.32030
# [39]	validation_0-logloss:0.29033	validation_1-logloss:0.31959
# [40]	validation_0-logloss:0.28977	validation_1-logloss:0.31656
# [41]	validation_0-logloss:0.28617	validation_1-logloss:0.31477
# [42]	validation_0-logloss:0.28495	validation_1-logloss:0.31603
# [43]	validation_0-logloss:0.28293	validation_1-logloss:0.31352
# [44]	validation_0-logloss:0.28157	validation_1-logloss:0.31168
# [45]	validation_0-logloss:0.27996	validation_1-logloss:0.31102
# [46]	validation_0-logloss:0.27503	validation_1-logloss:0.30779
# [47]	validation_0-logloss:0.27159	validation_1-logloss:0.30481
# [48]	validation_0-logloss:0.26771	validation_1-logloss:0.30372
# [49]	validation_0-logloss:0.26538	validation_1-logloss:0.30211
# [50]	validation_0-logloss:0.26382	validation_1-logloss:0.30021
# [51]	validation_0-logloss:0.26216	validation_1-logloss:0.29844
# [52]	validation_0-logloss:0.25863	validation_1-logloss:0.29547
# [53]	validation_0-logloss:0.25710	validation_1-logloss:0.29554
# [54]	validation_0-logloss:0.25500	validation_1-logloss:0.29381
# [55]	validation_0-logloss:0.25484	validation_1-logloss:0.29089
# [56]	validation_0-logloss:0.25211	validation_1-logloss:0.28727
# [57]	validation_0-logloss:0.25156	validation_1-logloss:0.28416
# [58]	validation_0-logloss:0.24894	validation_1-logloss:0.28295
# [59]	validation_0-logloss:0.24635	validation_1-logloss:0.28123
# [60]	validation_0-logloss:0.24266	validation_1-logloss:0.27549
# [61]	validation_0-logloss:0.24201	validation_1-logloss:0.27313
# [62]	validation_0-logloss:0.23995	validation_1-logloss:0.27222
# [63]	validation_0-logloss:0.23927	validation_1-logloss:0.27158
# [64]	validation_0-logloss:0.23701	validation_1-logloss:0.26947
# [65]	validation_0-logloss:0.23608	validation_1-logloss:0.26677
# [66]	validation_0-logloss:0.23532	validation_1-logloss:0.26603
# [67]	validation_0-logloss:0.23286	validation_1-logloss:0.26248
# [68]	validation_0-logloss:0.23197	validation_1-logloss:0.25979
# [69]	validation_0-logloss:0.22913	validation_1-logloss:0.25617
# [70]	validation_0-logloss:0.22687	validation_1-logloss:0.25325
# [71]	validation_0-logloss:0.22391	validation_1-logloss:0.25392
# [72]	validation_0-logloss:0.22278	validation_1-logloss:0.25247
# [73]	validation_0-logloss:0.22087	validation_1-logloss:0.25031
# [74]	validation_0-logloss:0.21953	validation_1-logloss:0.24998
# [75]	validation_0-logloss:0.21805	validation_1-logloss:0.24834
# [76]	validation_0-logloss:0.21637	validation_1-logloss:0.24606
# [77]	validation_0-logloss:0.21540	validation_1-logloss:0.24518
# [78]	validation_0-logloss:0.21300	validation_1-logloss:0.24285
# [79]	validation_0-logloss:0.21208	validation_1-logloss:0.24181
# [80]	validation_0-logloss:0.21128	validation_1-logloss:0.24032
# [81]	validation_0-logloss:0.21042	validation_1-logloss:0.23976
# [82]	validation_0-logloss:0.20828	validation_1-logloss:0.23684
# [83]	validation_0-logloss:0.20826	validation_1-logloss:0.23766
# [84]	validation_0-logloss:0.20804	validation_1-logloss:0.23671
# [85]	validation_0-logloss:0.20703	validation_1-logloss:0.23522
# [86]	validation_0-logloss:0.20583	validation_1-logloss:0.23401
# [87]	validation_0-logloss:0.20421	validation_1-logloss:0.23220
# [88]	validation_0-logloss:0.20311	validation_1-logloss:0.23097
# [89]	validation_0-logloss:0.20203	validation_1-logloss:0.23186
# [90]	validation_0-logloss:0.19979	validation_1-logloss:0.23189
# [91]	validation_0-logloss:0.19689	validation_1-logloss:0.22877
# [92]	validation_0-logloss:0.19587	validation_1-logloss:0.22640
# [93]	validation_0-logloss:0.19478	validation_1-logloss:0.22315
# [94]	validation_0-logloss:0.19295	validation_1-logloss:0.22168
# [95]	validation_0-logloss:0.19220	validation_1-logloss:0.22020
# [96]	validation_0-logloss:0.19208	validation_1-logloss:0.21977
# [97]	validation_0-logloss:0.18974	validation_1-logloss:0.21600
# [98]	validation_0-logloss:0.18890	validation_1-logloss:0.21555
# [99]	validation_0-logloss:0.18633	validation_1-logloss:0.21302
# [0]	validation_0-logloss:0.52627	validation_1-logloss:0.54687
# [1]	validation_0-logloss:0.50585	validation_1-logloss:0.52242
# [2]	validation_0-logloss:0.48753	validation_1-logloss:0.50701
# [3]	validation_0-logloss:0.47436	validation_1-logloss:0.49088
# [4]	validation_0-logloss:0.45759	validation_1-logloss:0.47539
# [5]	validation_0-logloss:0.44611	validation_1-logloss:0.46911
# [6]	validation_0-logloss:0.43613	validation_1-logloss:0.46239
# [7]	validation_0-logloss:0.42674	validation_1-logloss:0.44974
# [8]	validation_0-logloss:0.41789	validation_1-logloss:0.44235
# [9]	validation_0-logloss:0.40886	validation_1-logloss:0.43464
# [10]	validation_0-logloss:0.40411	validation_1-logloss:0.42566
# [11]	validation_0-logloss:0.40031	validation_1-logloss:0.41687
# [12]	validation_0-logloss:0.39424	validation_1-logloss:0.41183
# [13]	validation_0-logloss:0.38661	validation_1-logloss:0.40554
# [14]	validation_0-logloss:0.38047	validation_1-logloss:0.40027
# [15]	validation_0-logloss:0.37580	validation_1-logloss:0.39573
# [16]	validation_0-logloss:0.37232	validation_1-logloss:0.39363
# [17]	validation_0-logloss:0.36429	validation_1-logloss:0.39363
# [18]	validation_0-logloss:0.35876	validation_1-logloss:0.38864
# [19]	validation_0-logloss:0.35446	validation_1-logloss:0.38869
# [20]	validation_0-logloss:0.35121	validation_1-logloss:0.38030
# [21]	validation_0-logloss:0.34780	validation_1-logloss:0.37763
# [22]	validation_0-logloss:0.34693	validation_1-logloss:0.37740
# [23]	validation_0-logloss:0.34376	validation_1-logloss:0.37342
# [24]	validation_0-logloss:0.34124	validation_1-logloss:0.36772
# [25]	validation_0-logloss:0.33841	validation_1-logloss:0.36557
# [26]	validation_0-logloss:0.33506	validation_1-logloss:0.36378
# [27]	validation_0-logloss:0.32941	validation_1-logloss:0.36104
# [28]	validation_0-logloss:0.32498	validation_1-logloss:0.35795
# [29]	validation_0-logloss:0.32283	validation_1-logloss:0.35502
# [30]	validation_0-logloss:0.31766	validation_1-logloss:0.35305
# [31]	validation_0-logloss:0.31321	validation_1-logloss:0.34472
# [32]	validation_0-logloss:0.31269	validation_1-logloss:0.34378
# [33]	validation_0-logloss:0.30531	validation_1-logloss:0.34303
# [34]	validation_0-logloss:0.30263	validation_1-logloss:0.33879
# [35]	validation_0-logloss:0.29668	validation_1-logloss:0.33405
# [36]	validation_0-logloss:0.29266	validation_1-logloss:0.33067
# [37]	validation_0-logloss:0.29059	validation_1-logloss:0.33042
# [38]	validation_0-logloss:0.28582	validation_1-logloss:0.33034
# [39]	validation_0-logloss:0.28037	validation_1-logloss:0.33171
# [40]	validation_0-logloss:0.28083	validation_1-logloss:0.32940
# [41]	validation_0-logloss:0.27816	validation_1-logloss:0.32668
# [42]	validation_0-logloss:0.27624	validation_1-logloss:0.32616
# [43]	validation_0-logloss:0.27555	validation_1-logloss:0.32274
# [44]	validation_0-logloss:0.27301	validation_1-logloss:0.32006
# [45]	validation_0-logloss:0.27020	validation_1-logloss:0.31938
# [46]	validation_0-logloss:0.26784	validation_1-logloss:0.31858
# [47]	validation_0-logloss:0.26284	validation_1-logloss:0.31681
# [48]	validation_0-logloss:0.26116	validation_1-logloss:0.31594
# [49]	validation_0-logloss:0.25809	validation_1-logloss:0.31571
# [50]	validation_0-logloss:0.25694	validation_1-logloss:0.31191
# [51]	validation_0-logloss:0.25343	validation_1-logloss:0.30788
# [52]	validation_0-logloss:0.25147	validation_1-logloss:0.30642
# [53]	validation_0-logloss:0.24823	validation_1-logloss:0.30740
# [54]	validation_0-logloss:0.24465	validation_1-logloss:0.30371
# [55]	validation_0-logloss:0.24270	validation_1-logloss:0.30226
# [56]	validation_0-logloss:0.24138	validation_1-logloss:0.29835
# [57]	validation_0-logloss:0.24035	validation_1-logloss:0.29489
# [58]	validation_0-logloss:0.23641	validation_1-logloss:0.29203
# [59]	validation_0-logloss:0.23427	validation_1-logloss:0.28868
# [60]	validation_0-logloss:0.23190	validation_1-logloss:0.28710
# [61]	validation_0-logloss:0.23136	validation_1-logloss:0.28463
# [62]	validation_0-logloss:0.22891	validation_1-logloss:0.28116
# [63]	validation_0-logloss:0.22688	validation_1-logloss:0.27841
# [64]	validation_0-logloss:0.22720	validation_1-logloss:0.27665
# [65]	validation_0-logloss:0.22633	validation_1-logloss:0.27553
# [66]	validation_0-logloss:0.22565	validation_1-logloss:0.27537
# [67]	validation_0-logloss:0.22524	validation_1-logloss:0.26959
# [68]	validation_0-logloss:0.22357	validation_1-logloss:0.26527
# [69]	validation_0-logloss:0.22124	validation_1-logloss:0.26254
# [70]	validation_0-logloss:0.21899	validation_1-logloss:0.25726
# [71]	validation_0-logloss:0.21772	validation_1-logloss:0.25283
# [72]	validation_0-logloss:0.21631	validation_1-logloss:0.25145
# [73]	validation_0-logloss:0.21461	validation_1-logloss:0.24998
# [74]	validation_0-logloss:0.21237	validation_1-logloss:0.24843
# [75]	validation_0-logloss:0.21110	validation_1-logloss:0.24806
# [76]	validation_0-logloss:0.20937	validation_1-logloss:0.24493
# [77]	validation_0-logloss:0.20896	validation_1-logloss:0.24452
# [78]	validation_0-logloss:0.20670	validation_1-logloss:0.24078
# [79]	validation_0-logloss:0.20562	validation_1-logloss:0.24071
# [80]	validation_0-logloss:0.20511	validation_1-logloss:0.24103
# [81]	validation_0-logloss:0.20352	validation_1-logloss:0.24252
# [82]	validation_0-logloss:0.20195	validation_1-logloss:0.24016
# [83]	validation_0-logloss:0.20196	validation_1-logloss:0.23930
# [84]	validation_0-logloss:0.20159	validation_1-logloss:0.23798
# [85]	validation_0-logloss:0.20098	validation_1-logloss:0.23623
# [86]	validation_0-logloss:0.19979	validation_1-logloss:0.23469
# [87]	validation_0-logloss:0.19867	validation_1-logloss:0.23633
# [88]	validation_0-logloss:0.19609	validation_1-logloss:0.23434
# [89]	validation_0-logloss:0.19516	validation_1-logloss:0.23542
# [90]	validation_0-logloss:0.19381	validation_1-logloss:0.23585
# [91]	validation_0-logloss:0.19161	validation_1-logloss:0.23121
# [92]	validation_0-logloss:0.19096	validation_1-logloss:0.22916
# [93]	validation_0-logloss:0.18910	validation_1-logloss:0.22770
# [94]	validation_0-logloss:0.18712	validation_1-logloss:0.22521
# [95]	validation_0-logloss:0.18668	validation_1-logloss:0.22287
# [96]	validation_0-logloss:0.18631	validation_1-logloss:0.22216
# [97]	validation_0-logloss:0.18596	validation_1-logloss:0.22003
# [98]	validation_0-logloss:0.18503	validation_1-logloss:0.22150
# [99]	validation_0-logloss:0.18278	validation_1-logloss:0.22183
# [100]	validation_0-logloss:0.18041	validation_1-logloss:0.22241
# [101]	validation_0-logloss:0.17922	validation_1-logloss:0.22125
# [102]	validation_0-logloss:0.17667	validation_1-logloss:0.21867
# [103]	validation_0-logloss:0.17559	validation_1-logloss:0.21545
# [104]	validation_0-logloss:0.17408	validation_1-logloss:0.21174
# [105]	validation_0-logloss:0.17415	validation_1-logloss:0.20820
# [106]	validation_0-logloss:0.17418	validation_1-logloss:0.20883
# [107]	validation_0-logloss:0.17257	validation_1-logloss:0.20643
# [108]	validation_0-logloss:0.17135	validation_1-logloss:0.20488
# [109]	validation_0-logloss:0.17081	validation_1-logloss:0.20248
# [110]	validation_0-logloss:0.16858	validation_1-logloss:0.20081
# [111]	validation_0-logloss:0.16651	validation_1-logloss:0.20077
# [112]	validation_0-logloss:0.16595	validation_1-logloss:0.19788
# [113]	validation_0-logloss:0.16509	validation_1-logloss:0.19687
# [114]	validation_0-logloss:0.16425	validation_1-logloss:0.19454
# [115]	validation_0-logloss:0.16397	validation_1-logloss:0.19474
# [116]	validation_0-logloss:0.16286	validation_1-logloss:0.19538
# [117]	validation_0-logloss:0.16219	validation_1-logloss:0.19469
# [118]	validation_0-logloss:0.16156	validation_1-logloss:0.19465
# [119]	validation_0-logloss:0.16155	validation_1-logloss:0.19236
# [120]	validation_0-logloss:0.16111	validation_1-logloss:0.19215
# [121]	validation_0-logloss:0.16058	validation_1-logloss:0.19076
# [122]	validation_0-logloss:0.15999	validation_1-logloss:0.19089
# [123]	validation_0-logloss:0.15874	validation_1-logloss:0.19045
# [124]	validation_0-logloss:0.15814	validation_1-logloss:0.18880
# [125]	validation_0-logloss:0.15745	validation_1-logloss:0.18645
# [126]	validation_0-logloss:0.15679	validation_1-logloss:0.18413
# [127]	validation_0-logloss:0.15641	validation_1-logloss:0.18180
# [128]	validation_0-logloss:0.15533	validation_1-logloss:0.18304
# [129]	validation_0-logloss:0.15385	validation_1-logloss:0.18236
# [130]	validation_0-logloss:0.15281	validation_1-logloss:0.18108
# [131]	validation_0-logloss:0.15110	validation_1-logloss:0.18029
# [132]	validation_0-logloss:0.14981	validation_1-logloss:0.18051
# [133]	validation_0-logloss:0.14989	validation_1-logloss:0.17831
# [134]	validation_0-logloss:0.14901	validation_1-logloss:0.17606
# [135]	validation_0-logloss:0.14821	validation_1-logloss:0.17428
# [136]	validation_0-logloss:0.14810	validation_1-logloss:0.17336
# [137]	validation_0-logloss:0.14627	validation_1-logloss:0.17070
# [138]	validation_0-logloss:0.14551	validation_1-logloss:0.17015
# [139]	validation_0-logloss:0.14529	validation_1-logloss:0.16851
# [140]	validation_0-logloss:0.14537	validation_1-logloss:0.16677
# [141]	validation_0-logloss:0.14389	validation_1-logloss:0.16487
# [142]	validation_0-logloss:0.14341	validation_1-logloss:0.16498
# [143]	validation_0-logloss:0.14229	validation_1-logloss:0.16424
# [144]	validation_0-logloss:0.14130	validation_1-logloss:0.16340
# [145]	validation_0-logloss:0.13974	validation_1-logloss:0.16148
# [146]	validation_0-logloss:0.13913	validation_1-logloss:0.15860
# [147]	validation_0-logloss:0.13832	validation_1-logloss:0.15869
# [148]	validation_0-logloss:0.13758	validation_1-logloss:0.15633
# [149]	validation_0-logloss:0.13676	validation_1-logloss:0.15535
# [150]	validation_0-logloss:0.13619	validation_1-logloss:0.15488
# [151]	validation_0-logloss:0.13600	validation_1-logloss:0.15446
# [152]	validation_0-logloss:0.13486	validation_1-logloss:0.15256
# [153]	validation_0-logloss:0.13354	validation_1-logloss:0.15042
# [154]	validation_0-logloss:0.13269	validation_1-logloss:0.15025
# [155]	validation_0-logloss:0.13161	validation_1-logloss:0.15032
# [156]	validation_0-logloss:0.13189	validation_1-logloss:0.14956
# [157]	validation_0-logloss:0.13134	validation_1-logloss:0.14888
# [158]	validation_0-logloss:0.13054	validation_1-logloss:0.14869
# [159]	validation_0-logloss:0.12919	validation_1-logloss:0.14731
# [160]	validation_0-logloss:0.12852	validation_1-logloss:0.14771
# [161]	validation_0-logloss:0.12869	validation_1-logloss:0.14806
# [162]	validation_0-logloss:0.12857	validation_1-logloss:0.14745
# [163]	validation_0-logloss:0.12769	validation_1-logloss:0.14739
# [164]	validation_0-logloss:0.12713	validation_1-logloss:0.14683
# [165]	validation_0-logloss:0.12603	validation_1-logloss:0.14518
# [166]	validation_0-logloss:0.12629	validation_1-logloss:0.14420
# [167]	validation_0-logloss:0.12527	validation_1-logloss:0.14234
# [168]	validation_0-logloss:0.12471	validation_1-logloss:0.14364
# [169]	validation_0-logloss:0.12353	validation_1-logloss:0.14200
# [170]	validation_0-logloss:0.12327	validation_1-logloss:0.14178
# [171]	validation_0-logloss:0.12165	validation_1-logloss:0.14153
# [172]	validation_0-logloss:0.12094	validation_1-logloss:0.14039
# [173]	validation_0-logloss:0.11985	validation_1-logloss:0.13805
# [174]	validation_0-logloss:0.11945	validation_1-logloss:0.13788
# [175]	validation_0-logloss:0.11847	validation_1-logloss:0.13813
# [176]	validation_0-logloss:0.11812	validation_1-logloss:0.13732
# [177]	validation_0-logloss:0.11779	validation_1-logloss:0.13729
# [178]	validation_0-logloss:0.11722	validation_1-logloss:0.13685
# [179]	validation_0-logloss:0.11637	validation_1-logloss:0.13608
# [180]	validation_0-logloss:0.11620	validation_1-logloss:0.13501
# [181]	validation_0-logloss:0.11536	validation_1-logloss:0.13540
# [182]	validation_0-logloss:0.11494	validation_1-logloss:0.13559
# [183]	validation_0-logloss:0.11462	validation_1-logloss:0.13472
# [184]	validation_0-logloss:0.11466	validation_1-logloss:0.13266
# [185]	validation_0-logloss:0.11352	validation_1-logloss:0.13115
# [186]	validation_0-logloss:0.11319	validation_1-logloss:0.13122
# [187]	validation_0-logloss:0.11315	validation_1-logloss:0.13026
# [188]	validation_0-logloss:0.11268	validation_1-logloss:0.12969
# [189]	validation_0-logloss:0.11196	validation_1-logloss:0.13011
# [190]	validation_0-logloss:0.11186	validation_1-logloss:0.12985
# [191]	validation_0-logloss:0.11061	validation_1-logloss:0.13020
# [192]	validation_0-logloss:0.11032	validation_1-logloss:0.13054
# [193]	validation_0-logloss:0.10953	validation_1-logloss:0.13023
# [194]	validation_0-logloss:0.10863	validation_1-logloss:0.12944
# [195]	validation_0-logloss:0.10821	validation_1-logloss:0.12778
# [196]	validation_0-logloss:0.10794	validation_1-logloss:0.12696
# [197]	validation_0-logloss:0.10731	validation_1-logloss:0.12704
# [198]	validation_0-logloss:0.10746	validation_1-logloss:0.12588
# [199]	validation_0-logloss:0.10737	validation_1-logloss:0.12525
# [200]	validation_0-logloss:0.10719	validation_1-logloss:0.12385
# [201]	validation_0-logloss:0.10680	validation_1-logloss:0.12339
# [202]	validation_0-logloss:0.10640	validation_1-logloss:0.12374
# [203]	validation_0-logloss:0.10629	validation_1-logloss:0.12337
# [204]	validation_0-logloss:0.10629	validation_1-logloss:0.12388
# [205]	validation_0-logloss:0.10665	validation_1-logloss:0.12322
# [206]	validation_0-logloss:0.10696	validation_1-logloss:0.12218
# [207]	validation_0-logloss:0.10621	validation_1-logloss:0.12268
# [208]	validation_0-logloss:0.10552	validation_1-logloss:0.12360
# [209]	validation_0-logloss:0.10507	validation_1-logloss:0.12266
# [210]	validation_0-logloss:0.10443	validation_1-logloss:0.12172
# [211]	validation_0-logloss:0.10317	validation_1-logloss:0.12182
# [212]	validation_0-logloss:0.10289	validation_1-logloss:0.12188
# [213]	validation_0-logloss:0.10265	validation_1-logloss:0.12078
# [214]	validation_0-logloss:0.10260	validation_1-logloss:0.12084
# [215]	validation_0-logloss:0.10165	validation_1-logloss:0.12102
# [216]	validation_0-logloss:0.10197	validation_1-logloss:0.11964
# [217]	validation_0-logloss:0.10158	validation_1-logloss:0.11913
# [218]	validation_0-logloss:0.10145	validation_1-logloss:0.11861
# [219]	validation_0-logloss:0.10004	validation_1-logloss:0.11749
# [220]	validation_0-logloss:0.10040	validation_1-logloss:0.11644
# [221]	validation_0-logloss:0.10009	validation_1-logloss:0.11676
# [222]	validation_0-logloss:0.09966	validation_1-logloss:0.11630
# [223]	validation_0-logloss:0.09989	validation_1-logloss:0.11538
# [224]	validation_0-logloss:0.09978	validation_1-logloss:0.11527
# [225]	validation_0-logloss:0.09923	validation_1-logloss:0.11398
# [226]	validation_0-logloss:0.09866	validation_1-logloss:0.11223
# [227]	validation_0-logloss:0.09838	validation_1-logloss:0.11100
# [228]	validation_0-logloss:0.09777	validation_1-logloss:0.11128
# [229]	validation_0-logloss:0.09735	validation_1-logloss:0.11051
# [230]	validation_0-logloss:0.09654	validation_1-logloss:0.11100
# [231]	validation_0-logloss:0.09645	validation_1-logloss:0.11029
# [232]	validation_0-logloss:0.09659	validation_1-logloss:0.10933
# [233]	validation_0-logloss:0.09604	validation_1-logloss:0.10810
# [234]	validation_0-logloss:0.09592	validation_1-logloss:0.10736
# [235]	validation_0-logloss:0.09516	validation_1-logloss:0.10737
# [236]	validation_0-logloss:0.09478	validation_1-logloss:0.10678
# [237]	validation_0-logloss:0.09429	validation_1-logloss:0.10742
# [238]	validation_0-logloss:0.09416	validation_1-logloss:0.10713
# [239]	validation_0-logloss:0.09347	validation_1-logloss:0.10692
# [240]	validation_0-logloss:0.09253	validation_1-logloss:0.10739
# [241]	validation_0-logloss:0.09203	validation_1-logloss:0.10780
# [242]	validation_0-logloss:0.09174	validation_1-logloss:0.10637
# [243]	validation_0-logloss:0.09173	validation_1-logloss:0.10656
# [244]	validation_0-logloss:0.09137	validation_1-logloss:0.10615
# [245]	validation_0-logloss:0.09112	validation_1-logloss:0.10602
# [246]	validation_0-logloss:0.09082	validation_1-logloss:0.10587
# [247]	validation_0-logloss:0.09064	validation_1-logloss:0.10525
# [248]	validation_0-logloss:0.09086	validation_1-logloss:0.10433
# [249]	validation_0-logloss:0.09077	validation_1-logloss:0.10525
# [250]	validation_0-logloss:0.08999	validation_1-logloss:0.10541
# [251]	validation_0-logloss:0.08934	validation_1-logloss:0.10559
# [252]	validation_0-logloss:0.08858	validation_1-logloss:0.10458
# [253]	validation_0-logloss:0.08819	validation_1-logloss:0.10392
# [254]	validation_0-logloss:0.08848	validation_1-logloss:0.10347
# [255]	validation_0-logloss:0.08826	validation_1-logloss:0.10307
# [256]	validation_0-logloss:0.08763	validation_1-logloss:0.10215
# [257]	validation_0-logloss:0.08679	validation_1-logloss:0.10171
# [258]	validation_0-logloss:0.08688	validation_1-logloss:0.10246
# [259]	validation_0-logloss:0.08609	validation_1-logloss:0.10208
# [260]	validation_0-logloss:0.08589	validation_1-logloss:0.10175
# [261]	validation_0-logloss:0.08555	validation_1-logloss:0.10129
# [262]	validation_0-logloss:0.08552	validation_1-logloss:0.10077
# [263]	validation_0-logloss:0.08513	validation_1-logloss:0.10024
# [264]	validation_0-logloss:0.08471	validation_1-logloss:0.10014
# [265]	validation_0-logloss:0.08474	validation_1-logloss:0.09967
# [266]	validation_0-logloss:0.08469	validation_1-logloss:0.09970
# [267]	validation_0-logloss:0.08423	validation_1-logloss:0.09947
# [268]	validation_0-logloss:0.08422	validation_1-logloss:0.09904
# [269]	validation_0-logloss:0.08363	validation_1-logloss:0.09830
# [270]	validation_0-logloss:0.08304	validation_1-logloss:0.09779
# [271]	validation_0-logloss:0.08254	validation_1-logloss:0.09738
# [272]	validation_0-logloss:0.08285	validation_1-logloss:0.09673
# [273]	validation_0-logloss:0.08304	validation_1-logloss:0.09605
# [274]	validation_0-logloss:0.08281	validation_1-logloss:0.09535
# [275]	validation_0-logloss:0.08258	validation_1-logloss:0.09467
# [276]	validation_0-logloss:0.08233	validation_1-logloss:0.09412
# [277]	validation_0-logloss:0.08219	validation_1-logloss:0.09463
# [278]	validation_0-logloss:0.08192	validation_1-logloss:0.09450
# [279]	validation_0-logloss:0.08179	validation_1-logloss:0.09467
# [280]	validation_0-logloss:0.08155	validation_1-logloss:0.09504
# [281]	validation_0-logloss:0.08112	validation_1-logloss:0.09512
# [282]	validation_0-logloss:0.08082	validation_1-logloss:0.09539
# [283]	validation_0-logloss:0.08029	validation_1-logloss:0.09519
# [284]	validation_0-logloss:0.07981	validation_1-logloss:0.09429
# [285]	validation_0-logloss:0.07974	validation_1-logloss:0.09453
# [286]	validation_0-logloss:0.07967	validation_1-logloss:0.09459
# [287]	validation_0-logloss:0.07935	validation_1-logloss:0.09370
# [288]	validation_0-logloss:0.07913	validation_1-logloss:0.09330
# [289]	validation_0-logloss:0.07868	validation_1-logloss:0.09372
# [290]	validation_0-logloss:0.07840	validation_1-logloss:0.09359
# [291]	validation_0-logloss:0.07823	validation_1-logloss:0.09386
# [292]	validation_0-logloss:0.07793	validation_1-logloss:0.09340
# [293]	validation_0-logloss:0.07778	validation_1-logloss:0.09374
# [294]	validation_0-logloss:0.07743	validation_1-logloss:0.09305
# [295]	validation_0-logloss:0.07721	validation_1-logloss:0.09243
# [296]	validation_0-logloss:0.07698	validation_1-logloss:0.09212
# [297]	validation_0-logloss:0.07696	validation_1-logloss:0.09182
# [298]	validation_0-logloss:0.07669	validation_1-logloss:0.09123
# [299]	validation_0-logloss:0.07645	validation_1-logloss:0.09061
# [0]	validation_0-logloss:0.54059	validation_1-logloss:0.55703
# [1]	validation_0-logloss:0.53140	validation_1-logloss:0.54750
# [2]	validation_0-logloss:0.52236	validation_1-logloss:0.53877
# [3]	validation_0-logloss:0.51337	validation_1-logloss:0.53001
# [4]	validation_0-logloss:0.50773	validation_1-logloss:0.52336
# [5]	validation_0-logloss:0.50267	validation_1-logloss:0.51882
# [6]	validation_0-logloss:0.49870	validation_1-logloss:0.51484
# [7]	validation_0-logloss:0.49625	validation_1-logloss:0.51185
# [8]	validation_0-logloss:0.49263	validation_1-logloss:0.50684
# [9]	validation_0-logloss:0.48899	validation_1-logloss:0.50258
# [10]	validation_0-logloss:0.48727	validation_1-logloss:0.49999
# [11]	validation_0-logloss:0.48516	validation_1-logloss:0.49743
# [12]	validation_0-logloss:0.48072	validation_1-logloss:0.49353
# [13]	validation_0-logloss:0.47792	validation_1-logloss:0.49184
# [14]	validation_0-logloss:0.47800	validation_1-logloss:0.49087
# [15]	validation_0-logloss:0.47712	validation_1-logloss:0.49028
# [16]	validation_0-logloss:0.47362	validation_1-logloss:0.48623
# [17]	validation_0-logloss:0.47224	validation_1-logloss:0.48409
# [18]	validation_0-logloss:0.47018	validation_1-logloss:0.48178
# [19]	validation_0-logloss:0.46908	validation_1-logloss:0.48098
# [20]	validation_0-logloss:0.46665	validation_1-logloss:0.47943
# [21]	validation_0-logloss:0.46537	validation_1-logloss:0.47871
# [22]	validation_0-logloss:0.46592	validation_1-logloss:0.47911
# [23]	validation_0-logloss:0.46572	validation_1-logloss:0.47820
# [24]	validation_0-logloss:0.46655	validation_1-logloss:0.47938
# [25]	validation_0-logloss:0.46589	validation_1-logloss:0.47936
# [26]	validation_0-logloss:0.46607	validation_1-logloss:0.47937
# [27]	validation_0-logloss:0.46716	validation_1-logloss:0.47957
# [28]	validation_0-logloss:0.46560	validation_1-logloss:0.47847
# [29]	validation_0-logloss:0.46501	validation_1-logloss:0.47738
# [30]	validation_0-logloss:0.46500	validation_1-logloss:0.47754
# [31]	validation_0-logloss:0.46403	validation_1-logloss:0.47622
# [32]	validation_0-logloss:0.46537	validation_1-logloss:0.47643
# [33]	validation_0-logloss:0.46324	validation_1-logloss:0.47503
# [34]	validation_0-logloss:0.46124	validation_1-logloss:0.47342
# [35]	validation_0-logloss:0.45962	validation_1-logloss:0.47200
# [36]	validation_0-logloss:0.45797	validation_1-logloss:0.47009
# [37]	validation_0-logloss:0.45660	validation_1-logloss:0.46891
# [38]	validation_0-logloss:0.45673	validation_1-logloss:0.46898
# [39]	validation_0-logloss:0.45418	validation_1-logloss:0.46778
# [40]	validation_0-logloss:0.45520	validation_1-logloss:0.46813
# [41]	validation_0-logloss:0.45408	validation_1-logloss:0.46723
# [42]	validation_0-logloss:0.45438	validation_1-logloss:0.46755
# [43]	validation_0-logloss:0.45550	validation_1-logloss:0.46786
# [44]	validation_0-logloss:0.45383	validation_1-logloss:0.46630
# [45]	validation_0-logloss:0.45291	validation_1-logloss:0.46628
# [46]	validation_0-logloss:0.45108	validation_1-logloss:0.46558
# [47]	validation_0-logloss:0.45021	validation_1-logloss:0.46467
# [48]	validation_0-logloss:0.44962	validation_1-logloss:0.46436
# [49]	validation_0-logloss:0.44902	validation_1-logloss:0.46356
# [50]	validation_0-logloss:0.45021	validation_1-logloss:0.46392
# [51]	validation_0-logloss:0.45045	validation_1-logloss:0.46327
# [52]	validation_0-logloss:0.45102	validation_1-logloss:0.46357
# [53]	validation_0-logloss:0.45125	validation_1-logloss:0.46395
# [54]	validation_0-logloss:0.45189	validation_1-logloss:0.46490
# [55]	validation_0-logloss:0.45135	validation_1-logloss:0.46526
# [56]	validation_0-logloss:0.44914	validation_1-logloss:0.46347
# [57]	validation_0-logloss:0.44829	validation_1-logloss:0.46345
# [58]	validation_0-logloss:0.44852	validation_1-logloss:0.46378
# [59]	validation_0-logloss:0.44864	validation_1-logloss:0.46383
# [60]	validation_0-logloss:0.44760	validation_1-logloss:0.46270
# [61]	validation_0-logloss:0.44903	validation_1-logloss:0.46390
# [62]	validation_0-logloss:0.44876	validation_1-logloss:0.46405
# [63]	validation_0-logloss:0.44859	validation_1-logloss:0.46369
# [64]	validation_0-logloss:0.44826	validation_1-logloss:0.46335
# [65]	validation_0-logloss:0.44857	validation_1-logloss:0.46424
# [66]	validation_0-logloss:0.44825	validation_1-logloss:0.46484
# [67]	validation_0-logloss:0.44749	validation_1-logloss:0.46415
# [68]	validation_0-logloss:0.44716	validation_1-logloss:0.46365
# [69]	validation_0-logloss:0.44576	validation_1-logloss:0.46279
# [70]	validation_0-logloss:0.44638	validation_1-logloss:0.46297
# [71]	validation_0-logloss:0.44517	validation_1-logloss:0.46154
# [72]	validation_0-logloss:0.44546	validation_1-logloss:0.46171
# [73]	validation_0-logloss:0.44501	validation_1-logloss:0.46073
# [74]	validation_0-logloss:0.44501	validation_1-logloss:0.45989
# [75]	validation_0-logloss:0.44485	validation_1-logloss:0.45973
# [76]	validation_0-logloss:0.44366	validation_1-logloss:0.45886
# [77]	validation_0-logloss:0.44308	validation_1-logloss:0.45862
# [78]	validation_0-logloss:0.44126	validation_1-logloss:0.45749
# [79]	validation_0-logloss:0.44216	validation_1-logloss:0.45761
# [80]	validation_0-logloss:0.44120	validation_1-logloss:0.45663
# [81]	validation_0-logloss:0.44316	validation_1-logloss:0.45766
# [82]	validation_0-logloss:0.44454	validation_1-logloss:0.45856
# [83]	validation_0-logloss:0.44552	validation_1-logloss:0.45924
# [84]	validation_0-logloss:0.44730	validation_1-logloss:0.46062
# [85]	validation_0-logloss:0.44625	validation_1-logloss:0.45926
# [86]	validation_0-logloss:0.44735	validation_1-logloss:0.46006
# [87]	validation_0-logloss:0.44714	validation_1-logloss:0.46050
# [88]	validation_0-logloss:0.44692	validation_1-logloss:0.46023
# [89]	validation_0-logloss:0.44703	validation_1-logloss:0.45995
# [90]	validation_0-logloss:0.44605	validation_1-logloss:0.45982
# [91]	validation_0-logloss:0.44421	validation_1-logloss:0.45896
# [92]	validation_0-logloss:0.44331	validation_1-logloss:0.45823
# [93]	validation_0-logloss:0.44239	validation_1-logloss:0.45757
# [94]	validation_0-logloss:0.44086	validation_1-logloss:0.45598
# [95]	validation_0-logloss:0.44035	validation_1-logloss:0.45632
# [96]	validation_0-logloss:0.44076	validation_1-logloss:0.45697
# [97]	validation_0-logloss:0.44048	validation_1-logloss:0.45646
# [98]	validation_0-logloss:0.43991	validation_1-logloss:0.45611
# [99]	validation_0-logloss:0.43718	validation_1-logloss:0.45480
# [0]	validation_0-logloss:0.49256	validation_1-logloss:0.51173
# [1]	validation_0-logloss:0.44922	validation_1-logloss:0.47070
# [2]	validation_0-logloss:0.42217	validation_1-logloss:0.44105
# [3]	validation_0-logloss:0.40229	validation_1-logloss:0.41279
# [4]	validation_0-logloss:0.38499	validation_1-logloss:0.40116
# [5]	validation_0-logloss:0.36975	validation_1-logloss:0.38413
# [6]	validation_0-logloss:0.35423	validation_1-logloss:0.36993
# [7]	validation_0-logloss:0.34715	validation_1-logloss:0.35938
# [8]	validation_0-logloss:0.34022	validation_1-logloss:0.35251
# [9]	validation_0-logloss:0.33063	validation_1-logloss:0.34783
# [10]	validation_0-logloss:0.32355	validation_1-logloss:0.33846
# [11]	validation_0-logloss:0.31317	validation_1-logloss:0.33195
# [12]	validation_0-logloss:0.30397	validation_1-logloss:0.32397
# [13]	validation_0-logloss:0.29526	validation_1-logloss:0.31486
# [14]	validation_0-logloss:0.29003	validation_1-logloss:0.30924
# [15]	validation_0-logloss:0.28272	validation_1-logloss:0.30222
# [16]	validation_0-logloss:0.27344	validation_1-logloss:0.29731
# [17]	validation_0-logloss:0.26677	validation_1-logloss:0.29560
# [18]	validation_0-logloss:0.26205	validation_1-logloss:0.29148
# [19]	validation_0-logloss:0.25764	validation_1-logloss:0.28555
# [20]	validation_0-logloss:0.25475	validation_1-logloss:0.28050
# [21]	validation_0-logloss:0.25253	validation_1-logloss:0.28017
# [22]	validation_0-logloss:0.24715	validation_1-logloss:0.27571
# [23]	validation_0-logloss:0.24234	validation_1-logloss:0.27093
# [24]	validation_0-logloss:0.23832	validation_1-logloss:0.26366
# [25]	validation_0-logloss:0.23359	validation_1-logloss:0.25982
# [26]	validation_0-logloss:0.23064	validation_1-logloss:0.25736
# [27]	validation_0-logloss:0.22458	validation_1-logloss:0.24962
# [28]	validation_0-logloss:0.22196	validation_1-logloss:0.24619
# [29]	validation_0-logloss:0.21766	validation_1-logloss:0.24393
# [30]	validation_0-logloss:0.21410	validation_1-logloss:0.23901
# [31]	validation_0-logloss:0.20712	validation_1-logloss:0.23065
# [32]	validation_0-logloss:0.20579	validation_1-logloss:0.22894
# [33]	validation_0-logloss:0.20250	validation_1-logloss:0.22673
# [34]	validation_0-logloss:0.19903	validation_1-logloss:0.22229
# [35]	validation_0-logloss:0.19515	validation_1-logloss:0.22034
# [36]	validation_0-logloss:0.19115	validation_1-logloss:0.21734
# [37]	validation_0-logloss:0.18802	validation_1-logloss:0.21182
# [38]	validation_0-logloss:0.18488	validation_1-logloss:0.20941
# [39]	validation_0-logloss:0.18116	validation_1-logloss:0.20533
# [40]	validation_0-logloss:0.17904	validation_1-logloss:0.20390
# [41]	validation_0-logloss:0.17491	validation_1-logloss:0.20030
# [42]	validation_0-logloss:0.17370	validation_1-logloss:0.19825
# [43]	validation_0-logloss:0.17322	validation_1-logloss:0.19757
# [44]	validation_0-logloss:0.17077	validation_1-logloss:0.19523
# [45]	validation_0-logloss:0.17011	validation_1-logloss:0.19215
# [46]	validation_0-logloss:0.16608	validation_1-logloss:0.19222
# [47]	validation_0-logloss:0.16290	validation_1-logloss:0.18968
# [48]	validation_0-logloss:0.16067	validation_1-logloss:0.18604
# [49]	validation_0-logloss:0.15590	validation_1-logloss:0.18294
# [50]	validation_0-logloss:0.15529	validation_1-logloss:0.18333
# [51]	validation_0-logloss:0.15198	validation_1-logloss:0.18183
# [52]	validation_0-logloss:0.15112	validation_1-logloss:0.17948
# [53]	validation_0-logloss:0.14936	validation_1-logloss:0.17950
# [54]	validation_0-logloss:0.14697	validation_1-logloss:0.17774
# [55]	validation_0-logloss:0.14471	validation_1-logloss:0.17699
# [56]	validation_0-logloss:0.14248	validation_1-logloss:0.17333
# [57]	validation_0-logloss:0.14147	validation_1-logloss:0.17138
# [58]	validation_0-logloss:0.14016	validation_1-logloss:0.16717
# [59]	validation_0-logloss:0.13897	validation_1-logloss:0.16259
# [60]	validation_0-logloss:0.13951	validation_1-logloss:0.16226
# [61]	validation_0-logloss:0.13860	validation_1-logloss:0.16114
# [62]	validation_0-logloss:0.13768	validation_1-logloss:0.16077
# [63]	validation_0-logloss:0.13661	validation_1-logloss:0.15964
# [64]	validation_0-logloss:0.13543	validation_1-logloss:0.15898
# [65]	validation_0-logloss:0.13451	validation_1-logloss:0.15720
# [66]	validation_0-logloss:0.13271	validation_1-logloss:0.15520
# [67]	validation_0-logloss:0.13196	validation_1-logloss:0.15487
# [68]	validation_0-logloss:0.13140	validation_1-logloss:0.15427
# [69]	validation_0-logloss:0.12988	validation_1-logloss:0.15434
# [70]	validation_0-logloss:0.12925	validation_1-logloss:0.15363
# [71]	validation_0-logloss:0.12873	validation_1-logloss:0.15220
# [72]	validation_0-logloss:0.12834	validation_1-logloss:0.15127
# [73]	validation_0-logloss:0.12488	validation_1-logloss:0.14969
# [74]	validation_0-logloss:0.12472	validation_1-logloss:0.14950
# [75]	validation_0-logloss:0.12362	validation_1-logloss:0.14695
# [76]	validation_0-logloss:0.12253	validation_1-logloss:0.14638
# [77]	validation_0-logloss:0.12237	validation_1-logloss:0.14601
# [78]	validation_0-logloss:0.12163	validation_1-logloss:0.14588
# [79]	validation_0-logloss:0.12158	validation_1-logloss:0.14522
# [80]	validation_0-logloss:0.12036	validation_1-logloss:0.14408
# [81]	validation_0-logloss:0.11970	validation_1-logloss:0.14391
# [82]	validation_0-logloss:0.11871	validation_1-logloss:0.14278
# [83]	validation_0-logloss:0.11765	validation_1-logloss:0.14289
# [84]	validation_0-logloss:0.11801	validation_1-logloss:0.14269
# [85]	validation_0-logloss:0.11696	validation_1-logloss:0.14118
# [86]	validation_0-logloss:0.11610	validation_1-logloss:0.14102
# [87]	validation_0-logloss:0.11558	validation_1-logloss:0.14077
# [88]	validation_0-logloss:0.11450	validation_1-logloss:0.13848
# [89]	validation_0-logloss:0.11405	validation_1-logloss:0.13736
# [90]	validation_0-logloss:0.11338	validation_1-logloss:0.13656
# [91]	validation_0-logloss:0.11283	validation_1-logloss:0.13580
# [92]	validation_0-logloss:0.11251	validation_1-logloss:0.13479
# [93]	validation_0-logloss:0.11190	validation_1-logloss:0.13472
# [94]	validation_0-logloss:0.11073	validation_1-logloss:0.13407
# [95]	validation_0-logloss:0.10994	validation_1-logloss:0.13343
# [96]	validation_0-logloss:0.10934	validation_1-logloss:0.13273
# [97]	validation_0-logloss:0.10859	validation_1-logloss:0.13190
# [98]	validation_0-logloss:0.10725	validation_1-logloss:0.13020
# [99]	validation_0-logloss:0.10654	validation_1-logloss:0.13009
# [0]	validation_0-logloss:0.54207	validation_1-logloss:0.56217
# [1]	validation_0-logloss:0.53479	validation_1-logloss:0.55848
# [2]	validation_0-logloss:0.52704	validation_1-logloss:0.54931
# [3]	validation_0-logloss:0.52133	validation_1-logloss:0.54438
# [4]	validation_0-logloss:0.51451	validation_1-logloss:0.53803
# [5]	validation_0-logloss:0.50895	validation_1-logloss:0.53244
# [6]	validation_0-logloss:0.50413	validation_1-logloss:0.52705
# [7]	validation_0-logloss:0.49975	validation_1-logloss:0.52138
# [8]	validation_0-logloss:0.49589	validation_1-logloss:0.51817
# [9]	validation_0-logloss:0.49274	validation_1-logloss:0.51401
# [10]	validation_0-logloss:0.48885	validation_1-logloss:0.51126
# [11]	validation_0-logloss:0.48611	validation_1-logloss:0.50778
# [12]	validation_0-logloss:0.48263	validation_1-logloss:0.50436
# [13]	validation_0-logloss:0.48045	validation_1-logloss:0.50206
# [14]	validation_0-logloss:0.47805	validation_1-logloss:0.49931
# [15]	validation_0-logloss:0.47671	validation_1-logloss:0.49813
# [16]	validation_0-logloss:0.47417	validation_1-logloss:0.49601
# [17]	validation_0-logloss:0.47264	validation_1-logloss:0.49489
# [18]	validation_0-logloss:0.47159	validation_1-logloss:0.49415
# [19]	validation_0-logloss:0.47034	validation_1-logloss:0.49411
# [20]	validation_0-logloss:0.46894	validation_1-logloss:0.49215
# [21]	validation_0-logloss:0.46788	validation_1-logloss:0.49145
# [22]	validation_0-logloss:0.46638	validation_1-logloss:0.49111
# [23]	validation_0-logloss:0.46531	validation_1-logloss:0.49049
# [24]	validation_0-logloss:0.46468	validation_1-logloss:0.48999
# [25]	validation_0-logloss:0.46441	validation_1-logloss:0.48905
# [26]	validation_0-logloss:0.46408	validation_1-logloss:0.48801
# [27]	validation_0-logloss:0.46349	validation_1-logloss:0.48768
# [28]	validation_0-logloss:0.46248	validation_1-logloss:0.48683
# [29]	validation_0-logloss:0.46101	validation_1-logloss:0.48513
# [30]	validation_0-logloss:0.45960	validation_1-logloss:0.48371
# [31]	validation_0-logloss:0.45885	validation_1-logloss:0.48331
# [32]	validation_0-logloss:0.45930	validation_1-logloss:0.48321
# [33]	validation_0-logloss:0.45841	validation_1-logloss:0.48304
# [34]	validation_0-logloss:0.45754	validation_1-logloss:0.48198
# [35]	validation_0-logloss:0.45742	validation_1-logloss:0.48211
# [36]	validation_0-logloss:0.45684	validation_1-logloss:0.48117
# [37]	validation_0-logloss:0.45572	validation_1-logloss:0.48092
# [38]	validation_0-logloss:0.45558	validation_1-logloss:0.48065
# [39]	validation_0-logloss:0.45464	validation_1-logloss:0.48009
# [40]	validation_0-logloss:0.45406	validation_1-logloss:0.47980
# [41]	validation_0-logloss:0.45373	validation_1-logloss:0.47896
# [42]	validation_0-logloss:0.45369	validation_1-logloss:0.47897
# [43]	validation_0-logloss:0.45378	validation_1-logloss:0.47885
# [44]	validation_0-logloss:0.45340	validation_1-logloss:0.47857
# [45]	validation_0-logloss:0.45377	validation_1-logloss:0.47859
# [46]	validation_0-logloss:0.45262	validation_1-logloss:0.47832
# [47]	validation_0-logloss:0.45216	validation_1-logloss:0.47726
# [48]	validation_0-logloss:0.45191	validation_1-logloss:0.47718
# [49]	validation_0-logloss:0.45050	validation_1-logloss:0.47633
# [50]	validation_0-logloss:0.45063	validation_1-logloss:0.47642
# [51]	validation_0-logloss:0.44982	validation_1-logloss:0.47535
# [52]	validation_0-logloss:0.44970	validation_1-logloss:0.47521
# [53]	validation_0-logloss:0.44965	validation_1-logloss:0.47549
# [54]	validation_0-logloss:0.44945	validation_1-logloss:0.47484
# [55]	validation_0-logloss:0.44913	validation_1-logloss:0.47404
# [56]	validation_0-logloss:0.44838	validation_1-logloss:0.47315
# [57]	validation_0-logloss:0.44769	validation_1-logloss:0.47303
# [58]	validation_0-logloss:0.44751	validation_1-logloss:0.47248
# [59]	validation_0-logloss:0.44678	validation_1-logloss:0.47131
# [60]	validation_0-logloss:0.44720	validation_1-logloss:0.47179
# [61]	validation_0-logloss:0.44745	validation_1-logloss:0.47236
# [62]	validation_0-logloss:0.44753	validation_1-logloss:0.47282
# [63]	validation_0-logloss:0.44752	validation_1-logloss:0.47291
# [64]	validation_0-logloss:0.44676	validation_1-logloss:0.47156
# [65]	validation_0-logloss:0.44691	validation_1-logloss:0.47212
# [66]	validation_0-logloss:0.44624	validation_1-logloss:0.47149
# [67]	validation_0-logloss:0.44581	validation_1-logloss:0.47107
# [68]	validation_0-logloss:0.44610	validation_1-logloss:0.47078
# [69]	validation_0-logloss:0.44556	validation_1-logloss:0.47045
# [70]	validation_0-logloss:0.44527	validation_1-logloss:0.47038
# [71]	validation_0-logloss:0.44523	validation_1-logloss:0.47002
# [72]	validation_0-logloss:0.44584	validation_1-logloss:0.47058
# [73]	validation_0-logloss:0.44456	validation_1-logloss:0.47013
# [74]	validation_0-logloss:0.44501	validation_1-logloss:0.47077
# [75]	validation_0-logloss:0.44514	validation_1-logloss:0.47038
# [76]	validation_0-logloss:0.44400	validation_1-logloss:0.46997
# [77]	validation_0-logloss:0.44356	validation_1-logloss:0.46986
# [78]	validation_0-logloss:0.44322	validation_1-logloss:0.47001
# [79]	validation_0-logloss:0.44370	validation_1-logloss:0.47082
# [80]	validation_0-logloss:0.44292	validation_1-logloss:0.47011
# [81]	validation_0-logloss:0.44278	validation_1-logloss:0.46950
# [82]	validation_0-logloss:0.44288	validation_1-logloss:0.46940
# [83]	validation_0-logloss:0.44264	validation_1-logloss:0.46910
# [84]	validation_0-logloss:0.44333	validation_1-logloss:0.46924
# [85]	validation_0-logloss:0.44323	validation_1-logloss:0.46844
# [86]	validation_0-logloss:0.44308	validation_1-logloss:0.46842
# [87]	validation_0-logloss:0.44295	validation_1-logloss:0.46838
# [88]	validation_0-logloss:0.44287	validation_1-logloss:0.46827
# [89]	validation_0-logloss:0.44266	validation_1-logloss:0.46758
# [90]	validation_0-logloss:0.44267	validation_1-logloss:0.46708
# [91]	validation_0-logloss:0.44250	validation_1-logloss:0.46618
# [92]	validation_0-logloss:0.44187	validation_1-logloss:0.46584
# [93]	validation_0-logloss:0.44167	validation_1-logloss:0.46628
# [94]	validation_0-logloss:0.44093	validation_1-logloss:0.46567
# [95]	validation_0-logloss:0.44052	validation_1-logloss:0.46538
# [96]	validation_0-logloss:0.44020	validation_1-logloss:0.46527
# [97]	validation_0-logloss:0.43977	validation_1-logloss:0.46480
# [98]	validation_0-logloss:0.43968	validation_1-logloss:0.46423
# [99]	validation_0-logloss:0.43874	validation_1-logloss:0.46390
# [0]	validation_0-logloss:0.54142	validation_1-logloss:0.55528
# [1]	validation_0-logloss:0.53454	validation_1-logloss:0.54747
# [2]	validation_0-logloss:0.52403	validation_1-logloss:0.53722
# [3]	validation_0-logloss:0.51661	validation_1-logloss:0.53121
# [4]	validation_0-logloss:0.50992	validation_1-logloss:0.52408
# [5]	validation_0-logloss:0.50537	validation_1-logloss:0.52047
# [6]	validation_0-logloss:0.50185	validation_1-logloss:0.51723
# [7]	validation_0-logloss:0.49844	validation_1-logloss:0.51405
# [8]	validation_0-logloss:0.49501	validation_1-logloss:0.50925
# [9]	validation_0-logloss:0.49133	validation_1-logloss:0.50470
# [10]	validation_0-logloss:0.48971	validation_1-logloss:0.50258
# [11]	validation_0-logloss:0.48905	validation_1-logloss:0.50124
# [12]	validation_0-logloss:0.48550	validation_1-logloss:0.49782
# [13]	validation_0-logloss:0.48327	validation_1-logloss:0.49526
# [14]	validation_0-logloss:0.48146	validation_1-logloss:0.49292
# [15]	validation_0-logloss:0.47864	validation_1-logloss:0.49033
# [16]	validation_0-logloss:0.47666	validation_1-logloss:0.48939
# [17]	validation_0-logloss:0.47536	validation_1-logloss:0.48837
# [18]	validation_0-logloss:0.47442	validation_1-logloss:0.48814
# [19]	validation_0-logloss:0.47444	validation_1-logloss:0.48828
# [20]	validation_0-logloss:0.47123	validation_1-logloss:0.48486
# [21]	validation_0-logloss:0.46860	validation_1-logloss:0.48272
# [22]	validation_0-logloss:0.46994	validation_1-logloss:0.48359
# [23]	validation_0-logloss:0.46989	validation_1-logloss:0.48322
# [24]	validation_0-logloss:0.46976	validation_1-logloss:0.48243
# [25]	validation_0-logloss:0.46970	validation_1-logloss:0.48285
# [26]	validation_0-logloss:0.46867	validation_1-logloss:0.48209
# [27]	validation_0-logloss:0.46979	validation_1-logloss:0.48337
# [28]	validation_0-logloss:0.46881	validation_1-logloss:0.48306
# [29]	validation_0-logloss:0.46748	validation_1-logloss:0.48067
# [30]	validation_0-logloss:0.46725	validation_1-logloss:0.48032
# [31]	validation_0-logloss:0.46522	validation_1-logloss:0.47855
# [32]	validation_0-logloss:0.46817	validation_1-logloss:0.48015
# [33]	validation_0-logloss:0.46540	validation_1-logloss:0.47829
# [34]	validation_0-logloss:0.46351	validation_1-logloss:0.47678
# [35]	validation_0-logloss:0.46161	validation_1-logloss:0.47520
# [36]	validation_0-logloss:0.46044	validation_1-logloss:0.47350
# [37]	validation_0-logloss:0.45905	validation_1-logloss:0.47236
# [38]	validation_0-logloss:0.45894	validation_1-logloss:0.47216
# [39]	validation_0-logloss:0.45619	validation_1-logloss:0.46995
# [40]	validation_0-logloss:0.45768	validation_1-logloss:0.47112
# [41]	validation_0-logloss:0.45680	validation_1-logloss:0.47067
# [42]	validation_0-logloss:0.45596	validation_1-logloss:0.47010
# [43]	validation_0-logloss:0.45846	validation_1-logloss:0.47137
# [44]	validation_0-logloss:0.45741	validation_1-logloss:0.47061
# [45]	validation_0-logloss:0.45640	validation_1-logloss:0.47067
# [46]	validation_0-logloss:0.45419	validation_1-logloss:0.46963
# [47]	validation_0-logloss:0.45370	validation_1-logloss:0.46930
# [48]	validation_0-logloss:0.45360	validation_1-logloss:0.46928
# [49]	validation_0-logloss:0.45267	validation_1-logloss:0.46816
# [50]	validation_0-logloss:0.45304	validation_1-logloss:0.46972
# [51]	validation_0-logloss:0.45348	validation_1-logloss:0.47042
# [52]	validation_0-logloss:0.45360	validation_1-logloss:0.47040
# [53]	validation_0-logloss:0.45333	validation_1-logloss:0.47020
# [54]	validation_0-logloss:0.45291	validation_1-logloss:0.46943
# [55]	validation_0-logloss:0.45195	validation_1-logloss:0.46857
# [56]	validation_0-logloss:0.44995	validation_1-logloss:0.46649
# [57]	validation_0-logloss:0.45052	validation_1-logloss:0.46756
# [58]	validation_0-logloss:0.45020	validation_1-logloss:0.46696
# [59]	validation_0-logloss:0.45008	validation_1-logloss:0.46672
# [60]	validation_0-logloss:0.44941	validation_1-logloss:0.46574
# [61]	validation_0-logloss:0.45129	validation_1-logloss:0.46730
# [62]	validation_0-logloss:0.45049	validation_1-logloss:0.46720
# [63]	validation_0-logloss:0.45101	validation_1-logloss:0.46849
# [64]	validation_0-logloss:0.45144	validation_1-logloss:0.46791
# [65]	validation_0-logloss:0.45141	validation_1-logloss:0.46797
# [66]	validation_0-logloss:0.45169	validation_1-logloss:0.46839
# [67]	validation_0-logloss:0.45075	validation_1-logloss:0.46671
# [68]	validation_0-logloss:0.44960	validation_1-logloss:0.46569
# [69]	validation_0-logloss:0.44797	validation_1-logloss:0.46414
# [70]	validation_0-logloss:0.44756	validation_1-logloss:0.46337
# [71]	validation_0-logloss:0.44584	validation_1-logloss:0.46259
# [72]	validation_0-logloss:0.44604	validation_1-logloss:0.46301
# [73]	validation_0-logloss:0.44569	validation_1-logloss:0.46275
# [74]	validation_0-logloss:0.44636	validation_1-logloss:0.46247
# [75]	validation_0-logloss:0.44689	validation_1-logloss:0.46190
# [76]	validation_0-logloss:0.44585	validation_1-logloss:0.46109
# [77]	validation_0-logloss:0.44533	validation_1-logloss:0.46106
# [78]	validation_0-logloss:0.44277	validation_1-logloss:0.45913
# [79]	validation_0-logloss:0.44377	validation_1-logloss:0.46016
# [80]	validation_0-logloss:0.44349	validation_1-logloss:0.45989
# [81]	validation_0-logloss:0.44553	validation_1-logloss:0.46081
# [82]	validation_0-logloss:0.44667	validation_1-logloss:0.46127
# [83]	validation_0-logloss:0.44749	validation_1-logloss:0.46181
# [84]	validation_0-logloss:0.44783	validation_1-logloss:0.46143
# [85]	validation_0-logloss:0.44724	validation_1-logloss:0.46090
# [86]	validation_0-logloss:0.44947	validation_1-logloss:0.46218
# [87]	validation_0-logloss:0.45027	validation_1-logloss:0.46309
# [88]	validation_0-logloss:0.44946	validation_1-logloss:0.46272
# [89]	validation_0-logloss:0.44876	validation_1-logloss:0.46323
# [90]	validation_0-logloss:0.44757	validation_1-logloss:0.46294
# [91]	validation_0-logloss:0.44573	validation_1-logloss:0.46206
# [92]	validation_0-logloss:0.44577	validation_1-logloss:0.46191
# [93]	validation_0-logloss:0.44502	validation_1-logloss:0.46275
# [94]	validation_0-logloss:0.44323	validation_1-logloss:0.46110
# [95]	validation_0-logloss:0.44281	validation_1-logloss:0.46038
# [96]	validation_0-logloss:0.44346	validation_1-logloss:0.46093
# [97]	validation_0-logloss:0.44456	validation_1-logloss:0.46053
# [98]	validation_0-logloss:0.44477	validation_1-logloss:0.46077
# [99]	validation_0-logloss:0.44318	validation_1-logloss:0.45997
# Average Accuracy: 0.8715277777777778
# Average Precision: 0.7167572463768116
# Average Recall: 0.6666666666666666
# Average F1 Score: 0.6881230854915065
# Averaged Hyperparameters:
# colsample_bytree      0.616667
# learning_rate         0.133333
# max_depth             3.000000
# min_child_weight      1.333333
# n_estimators        133.333333
# reg_alpha             0.616667
# reg_lambda            0.666667
# scale_pos_weight      1.951430
# subsample             0.666667
# dtype: float64

# %%
from sklearn.model_selection import permutation_test_score

score, permutation_scores, pvalue = permutation_test_score(
    xgb_model_adjusted, X_adjusted, y, random_state=0
)

# %%
pvalue
# Out:
# 0.009900990099009901

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, average_precision_score

xgb_best_model = bayes_search.best_estimator_

y_true = test_y 

y_pred = xgb_best_model.predict(test_x[x_var_adjusted])
y_pred_prob = xgb_best_model.predict_proba(test_x[x_var_adjusted])[:, 1]  

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
auc_pr = average_precision_score(y_true, y_pred_prob)

print("Accuracy:", round(accuracy, 2))
print("Precision:", round(precision, 2))
print("Recall:", round(recall, 2))
print("F1 Score:", round(f1, 2))
print("AUC PR:", round(auc_pr, 2))
# Out:
# Accuracy: 0.99
# Precision: 0.93
# Recall: 1.0
# F1 Score: 0.96
# AUC PR: 1.0

# %%
import matplotlib.pyplot as plt

random_states = [0, 10, 20, 30, 40]
for rs in random_states:
    train_scores = []
    val_scores = []
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=rs)
    for train_idx, val_idx in cv.split(X, y):
        train_x, val_x = X.iloc[train_idx], X.iloc[val_idx]
        train_y, val_y = y.iloc[train_idx], y.iloc[val_idx]
        
        model = xgb.XGBClassifier(n_estimators=100, eval_metric='logloss')
        model.fit(train_x, train_y)
        
        train_pred = model.predict(train_x)
        val_pred = model.predict(val_x)
        
        train_scores.append(f1_score(train_y, train_pred))
        val_scores.append(f1_score(val_y, val_pred))

    plt.plot(val_scores, label=f'Random State {rs}')
    
plt.xlabel('Fold')
plt.ylabel('F1 Score')
plt.title('Validation F1 Score Across Different Random States')
plt.legend()
plt.show()

# %%
import shap

explainer = shap.Explainer(xgb_best_model)
shap_values = explainer(train_xgb[x_var_adjusted])

shap.summary_plot(shap_values, train_xgb[x_var_adjusted])

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values.values[0], train_xgb[x_var_adjusted].iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 shap.initjs()
#       2 shap.force_plot(explainer.expected_value, shap_values.values[0], train_xgb[x_var_adjusted].iloc[0])
#
# NameError: name 'shap' is not defined

# %%
shap.plots.bar(shap_values)

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import classification_report, roc_auc_score

train_xgb, test_xgb = train_test_split(random_sample, test_size=0.2, random_state=42)

evalset = [(train_xgb[x_var_adjusted], train_xgb[y_var]), (test_xgb[x_var_adjusted], test_xgb[y_var])]

xgb_best_model.fit(train_xgb[x_var_adjusted], train_xgb[y_var], eval_set=evalset, verbose=True)

y_pred_final = xgb_best_model.predict(test_xgb[x_var_adjusted])
y_pred_prob_final = xgb_best_model.predict_proba(test_xgb[x_var_adjusted])[:, 1]
# Out:
# [0]	validation_0-logloss:0.56224	validation_1-logloss:0.56961
# [1]	validation_0-logloss:0.50006	validation_1-logloss:0.50637
# [2]	validation_0-logloss:0.44693	validation_1-logloss:0.45241
# [3]	validation_0-logloss:0.40412	validation_1-logloss:0.41778
# [4]	validation_0-logloss:0.36397	validation_1-logloss:0.37638
# [5]	validation_0-logloss:0.32892	validation_1-logloss:0.34022
# [6]	validation_0-logloss:0.29815	validation_1-logloss:0.30847
# [7]	validation_0-logloss:0.27102	validation_1-logloss:0.28047
# [8]	validation_0-logloss:0.24892	validation_1-logloss:0.26310
# [9]	validation_0-logloss:0.22739	validation_1-logloss:0.24049
# [10]	validation_0-logloss:0.20823	validation_1-logloss:0.22035
# [11]	validation_0-logloss:0.19113	validation_1-logloss:0.20236
# [12]	validation_0-logloss:0.17583	validation_1-logloss:0.18625
# [13]	validation_0-logloss:0.16210	validation_1-logloss:0.17179
# [14]	validation_0-logloss:0.14977	validation_1-logloss:0.15879
# [15]	validation_0-logloss:0.13868	validation_1-logloss:0.14708
# [16]	validation_0-logloss:0.12867	validation_1-logloss:0.13652
# [17]	validation_0-logloss:0.11964	validation_1-logloss:0.12697
# [18]	validation_0-logloss:0.11228	validation_1-logloss:0.12143
# [19]	validation_0-logloss:0.10480	validation_1-logloss:0.11339
# [20]	validation_0-logloss:0.09801	validation_1-logloss:0.10609
# [21]	validation_0-logloss:0.09185	validation_1-logloss:0.09945
# [22]	validation_0-logloss:0.08624	validation_1-logloss:0.09342
# [23]	validation_0-logloss:0.08114	validation_1-logloss:0.08791
# [24]	validation_0-logloss:0.07648	validation_1-logloss:0.08289
# [25]	validation_0-logloss:0.07222	validation_1-logloss:0.07830
# [26]	validation_0-logloss:0.06833	validation_1-logloss:0.07410
# [27]	validation_0-logloss:0.06477	validation_1-logloss:0.07025
# [28]	validation_0-logloss:0.06150	validation_1-logloss:0.06672
# [29]	validation_0-logloss:0.05850	validation_1-logloss:0.06347
# [30]	validation_0-logloss:0.05574	validation_1-logloss:0.06049
# [31]	validation_0-logloss:0.05320	validation_1-logloss:0.05774
# [32]	validation_0-logloss:0.05086	validation_1-logloss:0.05521
# [33]	validation_0-logloss:0.04869	validation_1-logloss:0.05287
# [34]	validation_0-logloss:0.04670	validation_1-logloss:0.05071
# [35]	validation_0-logloss:0.04485	validation_1-logloss:0.04871
# [36]	validation_0-logloss:0.04314	validation_1-logloss:0.04685
# [37]	validation_0-logloss:0.04155	validation_1-logloss:0.04513
# [38]	validation_0-logloss:0.04007	validation_1-logloss:0.04353
# [39]	validation_0-logloss:0.03890	validation_1-logloss:0.04268
# [40]	validation_0-logloss:0.03761	validation_1-logloss:0.04127
# [41]	validation_0-logloss:0.03641	validation_1-logloss:0.03996
# [42]	validation_0-logloss:0.03529	validation_1-logloss:0.03873
# [43]	validation_0-logloss:0.03441	validation_1-logloss:0.03811
# [44]	validation_0-logloss:0.03342	validation_1-logloss:0.03701
# [45]	validation_0-logloss:0.03249	validation_1-logloss:0.03599
# [46]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [47]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [48]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [49]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [50]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [51]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [52]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [53]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [54]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [55]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [56]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [57]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [58]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [59]	validation_0-logloss:0.03163	validation_1-logloss:0.03503
# [60]	validation_0-logloss:0.03163	validation_1-logloss:0.03503

# %%
y_true = test_xgb[y_var]
y_pred = xgb_best_model.predict(test_xgb[x_var_adjusted])
y_pred_prob = xgb_best_model.predict_proba(test_xgb[x_var_adjusted])[:, 1]  

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

auc_pr = average_precision_score(y_true, y_pred_prob)

print("Accuracy:", round(accuracy,2))
print("Precision:", round(precision,2))
print("Recall:", round(recall,2))
print("F1 Score:", round(f1,2))
print("AUC PR:", round(auc_pr,2))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# AUC PR: 1.0

# %%
results = xgb_best_model.evals_result()

pyplot.plot(results['validation_0']['logloss'], label='train')
pyplot.plot(results['validation_1']['logloss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, average_precision_score

# Step 1: Use the best model to make predictions on the test set
y_true = df_test['clutch_performance']  # True labels from the test set
y_pred = xgb_best_model.predict(df_test[x_var_adjusted])  # Make predictions

# Step 2: Calculate performance metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
auc_pr = average_precision_score(y_true, xgb_best_model.predict_proba(df_test[x_var_adjusted])[:, 1])  # AUC-PR

# Step 3: Print the results
print("Test Set Metrics:")
print("Accuracy:", round(accuracy, 2))
print("Precision:", round(precision, 2))
print("Recall:", round(recall, 2))
print("F1 Score:", round(f1, 2))
print("AUC PR:", round(auc_pr, 2))
# Out:
# Test Set Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# AUC PR: 1.0

# %%
xgb_model.fit(train_xgb[x_var_adjusted], train_xgb[y_var])

y_train_pred = xgb_model.predict(train_xgb[x_var_adjusted])

y_test_pred = xgb_model.predict(test_xgb[x_var_adjusted])

train_accuracy = accuracy_score(train_xgb[y_var], y_train_pred)
train_precision = precision_score(train_xgb[y_var], y_train_pred)
train_recall = recall_score(train_xgb[y_var], y_train_pred)
train_f1 = f1_score(train_xgb[y_var], y_train_pred)

# Print results
print("Training Set Metrics:")
print(f"Accuracy: {train_accuracy:.2f}, Precision: {train_precision:.2f}, Recall: {train_recall:.2f}, F1 Score: {train_f1:.2f}")
# Out:
# Training Set Metrics:
# Accuracy: 1.00, Precision: 1.00, Recall: 1.00, F1 Score: 1.00

# %%
conf_matrix = confusion_matrix(y_pred_xgb, y_true_xgb)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

disp.plot()
plt.suptitle('Confusion Matrix for XGBoost')
plt.show()

# %%
x_var = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageClose', 'satPercentageTied', 'gameWinningGoals']
y_var = ['clutch_performance']
train, test = train_test_split(df_players_merged, test_size = 0.3)

random_forest_model = RandomForestClassifier(n_estimators=100)
random_forest_model.fit(train[x_var], train[y_var].values.ravel())
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import time

x_var_adjusted = ['usatPercentageClose', 'usatPercentageTied', 'satPercentageTied']
y_var = 'clutch_performance'

scale_pos_weight = (df_players_merged['clutch_performance'] == 0).sum() / (df_players_merged['clutch_performance'] == 1).sum()

param_grid = {
    'max_depth': [1, 3, 5, 7],
    'n_estimators': [100, 200, 300],
    'scale_pos_weight': [scale_pos_weight],
    'min_child_weight': [1, 3, 5],
    'learning_rate': [0.1, 0.3, 0.6, 0.8, 1.0],
    'reg_alpha': [0.1, 0.5, 1.0],
    'reg_lambda':[0.1, 0.5, 1.0]
    
}

random_search = RandomizedSearchCV(estimator = xgb_model, param_distributions = param_grid, cv = 5, n_jobs = -1,n_iter=100)

start_time = time.time()
random_search.fit(train_xgb[x_var_adjusted], train_xgb[y_var])
xgb_duration = time.time() - start_time

print("Best Parameters:", random_search.best_params_)
print ("Time: ", xgb_duration)

# %%
scores = cross_val_score(xgb_model, df_players_merged[x_var], df_players_merged[y_var].values.ravel(), cv=10)
scores
# Out:
# array([1.        , 0.97916667, 0.95833333, 1.        , 0.97916667,
#        0.95833333, 0.9787234 , 1.        , 1.        , 0.95744681])

# %%
scores.mean()
# Out:
# 0.9811170212765958

# %%
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Parameters: {'subsample': 0.65, 'scale_pos_weight': 4.804878048780488, 'n_estimators': 300, 'min_child_weight': 5, 'max_depth': 1, 'learning_rate': 0.1, 'gamma': 0.3, 'colsample_bytree': 0.75}
# Best Balanced Accuracy: 0.9749943039416724

# %%
best_model = random_search.best_estimator_
best_model.fit(train[x_var], train[y_var])

accuracy = best_model.score(test[x_var], test[y_var])
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9440559440559441

# %%
cv_scores = cross_val_score(best_model, df_players_merged[x_var], df_players_merged[y_var], cv=10)

cv_scores
# Out:
# array([0.9375    , 0.97916667, 0.95833333, 0.97916667, 0.97916667,
#        0.97916667, 0.95744681, 1.        , 0.9787234 , 0.95744681])

# %%
cv_scores.mean()
# Out:
# 0.9706117021276597

# %%
y_pred = best_model.predict(test[x_var])  
y_true = test[y_var]

precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.8055555555555556
# Recall: 0.9666666666666667
# F1 Score: 0.8787878787878789

# %%
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_true, y_pred)

display = PrecisionRecallDisplay(precision=precision, recall=recall)

display.plot()

plt.ylabel("Precision")
plt.xlabel("Recall")
plt.title("Precision-Recall Curve")

plt.show()

# %%
probability = best_model.predict_proba(test[x_var])[:, 1]

auc_pr = average_precision_score(test[y_var], probability)

auc_pr
# Out:
# 0.9817724867724869

# %%
conf_matrix = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

disp.plot()
plt.suptitle('Confusion Matrix for Predicting Clutch Goalscorers in NHL')
plt.show()

# %%
accuracy = (conf_matrix[0, 0] + conf_matrix[1, 1]) / np.sum(conf_matrix)
accuracy
# Out:
# 0.9440559440559441

# %%
df_players_merged['gameWinningGoalsPercentile'] = df_players_merged['gameWinningGoalsPercentile'].astype(str) + '%'
df_players_merged['tiedPercentile'] = df_players_merged['tiedPercentile'].astype(str) + '%'
df_players_merged['closePercentile'] = df_players_merged['closePercentile'].astype(str) + '%'
df_players_merged['final'] = df_players_merged['final'].astype(str) + '%'

# %%
df_players_merged.to_csv(r'C:\Users\shakj\Desktop\nhl_clutch_player_data1.csv', index=False)

# %%
df_players_merged
# Out:
#      playerId    skaterFullName  lastName positionCode teamAbbrevs  \
# 0     8478028  Fredrik Olofsson  Olofsson            L         COL
# 1     8475763       Kevin Hayes     Hayes            R         STL
# 2     8471698        T.J. Oshie     Oshie            R         WSH
# 3     8482259      Bobby McMann    McMann            C         TOR
# 4     8480748   Kiefer Sherwood  Sherwood            L         NSH
# ..        ...               ...       ...          ...         ...
# 471   8474870     Tyler Johnson   Johnson            C         CHI
# 472   8475913        Mark Stone     Stone            R         VGK
# 473   8478831    Kevin Stenlund  Stenlund            C         FLA
# 474   8476483    Rickard Rakell    Rakell            R         PIT
# 475   8474715  Cameron Atkinson  Atkinson            R         PHI
#
#      gamesPlayed shootsCatches  satPercentageClose  satPercentageTied  \
# 0             57             L                46.4               43.6
# 1             79             L                45.0               44.3
# 2             56             R                43.3               41.6
# 3             56             L                52.3               51.8
# 4             74             R                52.0               53.5
# ..           ...           ...                 ...                ...
# 471           67             R                37.4               37.3
# 472           63             R                45.5               43.1
# 473          105             R                48.8               51.1
# 474           70             R                52.7               52.8
# 475           70             R                48.6               46.3
#
#      usatPercentageTied  ...  satPercentageClosePercentile  \
# 0                  40.1  ...                         27.94
# 1                  43.0  ...                         20.48
# 2                  41.1  ...                         12.82
# 3                  50.9  ...                         72.90
# 4                  53.4  ...                         70.38
# ..                  ...  ...                           ...
# 471                37.7  ...                          1.16
# 472                42.1  ...                         21.85
# 473                48.8  ...                         44.33
# 474                52.5  ...                         76.05
# 475                49.8  ...                         42.86
#
#      satPercentageTiedPercentile  usatPercentageTiedPercentile  \
# 0                          15.13                          3.99
# 1                          18.28                         13.76
# 2                           8.61                          7.25
# 3                          67.65                         59.56
# 4                          78.26                         76.16
# ..                           ...                           ...
# 471                         1.68                          2.31
# 472                        13.34                         10.82
# 473                        61.03                         43.70
# 474                        74.16                         71.64
# 475                        28.47                         52.73
#
#      usatPercentageClosePercentile gameWinningGoalsPercentile tiedPercentile  \
# 0                            13.76                     36.97%          9.56%
# 1                            13.76                     55.67%         16.02%
# 2                            11.55                     80.78%          7.93%
# 3                            78.36                     13.34%          63.6%
# 4                            70.80                     55.67%         77.21%
# ..                             ...                        ...            ...
# 471                           0.84                     36.97%           2.0%
# 472                          20.80                     87.82%         12.08%
# 473                          33.82                     70.17%         52.36%
# 474                          66.49                     55.67%          72.9%
# 475                          68.70                     70.17%          40.6%
#
#      closePercentile   final  finalRank  clutch_performance
# 0             20.85%  23.91%      399.0                   0
# 1             17.12%  32.21%      355.0                   0
# 2             12.18%  38.35%      320.0                   0
# 3             75.63%   47.1%      267.0                   0
# 4             70.59%  66.61%      123.0                   0
# ..               ...     ...        ...                 ...
# 471             1.0%  15.69%      438.0                   0
# 472           21.33%  45.15%      281.0                   0
# 473           39.08%   55.5%      207.0                   0
# 474           71.27%  65.52%      130.0                   0
# 475           55.78%  56.98%      193.0                   0
#
# [476 rows x 26 columns]

# %%
df_players_merged['finalRank'] = df_players_merged['finalRank'].astype(int)

df_players_merged.rename(columns={'skaterFullName': 'Name', 'closePercentile': 'Close Percentile', 'tiedPercentile': 'Tied Percentile', 'closePercentile': 'Close Percentile', 'gameWinningGoalsPercentile': 'GWG Percentile', 'final': 'Clutch Percentile','finalRank': 'Rank'}, inplace=True)

df_players_merged[['Name', 'Close Percentile',  'Tied Percentile', 'Clutch Percentile', 'GWG Percentile', 'Rank']].sort_values('Rank', ascending=True).head(5)
# Out:
#                   Name Close Percentile Tied Percentile Clutch Percentile  \
# 399         Zach Hyman            97.0%          97.38%            97.73%
# 188      Sebastian Aho           96.96%          96.12%            97.63%
# 12         Seth Jarvis           96.64%          97.38%             97.2%
# 252  Andrei Svechnikov           98.37%          94.02%            96.12%
# 194       Sam Reinhart           93.48%          93.49%            96.09%
#
#     GWG Percentile  Rank
# 399         98.53%     1
# 188         99.26%     2
# 12          97.48%     3
# 252         96.01%     4
# 194         100.0%     5

# %%
df_players_merged[['Name', 'Close Percentile',  'Tied Percentile', 'GWG Percentile', 'Clutch Percentile', 'Rank']].sort_values('Rank', ascending=True).head(10)
# Out:
#                   Name Close Percentile Tied Percentile GWG Percentile  \
# 399         Zach Hyman            97.0%          97.38%         98.53%
# 188      Sebastian Aho           96.96%          96.12%         99.26%
# 12         Seth Jarvis           96.64%          97.38%         97.48%
# 252  Andrei Svechnikov           98.37%          94.02%         96.01%
# 194       Sam Reinhart           93.48%          93.49%         100.0%
# 338   Nathan MacKinnon           95.32%          93.65%         97.48%
# 110  Aleksander Barkov           94.54%           94.7%         96.01%
# 166     Mikko Rantanen           93.38%          91.23%         98.53%
# 87      Connor McDavid           97.84%          95.28%          91.6%
# 397     Artemi Panarin           90.44%          90.18%         97.48%
#
#     Clutch Percentile  Rank
# 399            97.73%     1
# 188            97.63%     2
# 12              97.2%     3
# 252            96.12%     4
# 194            96.09%     5
# 338            95.68%     6
# 110            95.18%     7
# 166             94.8%     8
# 87             94.58%     9
# 397            93.18%    10
